# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.distributions import Categorical
import os

# %%
# Hyperparameters
learning_rate = 0.0003
gamma = 0.99
lmbda = 0.95
eps_clip = 0.2
K_epochs = 4
T_horizon = 2000

# %%
# Policy Network
class ActorCritic(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.fc1 = nn.Linear(state_dim, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc_pi = nn.Linear(256, action_dim)
        self.fc_v = nn.Linear(256, 1)
        
        self.optimizer = optim.Adam(self.parameters(), lr=learning_rate)

    def pi(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = self.fc_pi(x)
        return Categorical(logits=x)
    
    def v(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        v = self.fc_v(x)
        return v

# %%
# PPO Agent
class PPO:
    def __init__(self, state_dim, action_dim):
        self.policy = ActorCritic(state_dim, action_dim)
        self.policy_old = ActorCritic(state_dim, action_dim)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.optimizer = self.policy.optimizer
        self.MseLoss = nn.MSELoss()

    def update(self, memory):
        rewards = []
        discounted_reward = 0
        for reward, is_terminal in zip(reversed(memory.rewards), reversed(memory.is_terminals)):
            if is_terminal:
                discounted_reward = 0
            discounted_reward = reward + (gamma * discounted_reward)
            rewards.insert(0, discounted_reward)

        rewards = torch.tensor(rewards, dtype=torch.float32)
        rewards = (rewards - rewards.mean()) / (rewards.std() + 1e-7)

        old_states = torch.squeeze(torch.stack(memory.states).detach())
        old_actions = torch.squeeze(torch.stack(memory.actions).detach())
        old_logprobs = torch.squeeze(torch.stack(memory.logprobs).detach())

        for _ in range(K_epochs):
            logprobs, state_values, dist_entropy = self.evaluate(old_states, old_actions)

            ratios = torch.exp(logprobs - old_logprobs.detach())

            advantages = rewards - state_values.detach()
            surr1 = ratios * advantages
            surr2 = torch.clamp(ratios, 1 - eps_clip, 1 + eps_clip) * advantages

            loss = -torch.min(surr1, surr2) + 0.5 * self.MseLoss(state_values, rewards) - 0.01 * dist_entropy

            self.optimizer.zero_grad()
            loss.mean().backward()
            self.optimizer.step()

        self.policy_old.load_state_dict(self.policy.state_dict())

    def evaluate(self, state, action):
        state_value = self.policy.v(state)
        dist = self.policy.pi(state)
        action_logprobs = dist.log_prob(action)
        dist_entropy = dist.entropy()
        return action_logprobs, torch.squeeze(state_value), dist_entropy

    def save(self, checkpoint_path):
        torch.save(self.policy.state_dict(), checkpoint_path)
        print(f"Model saved to {checkpoint_path}")

    def load(self, checkpoint_path):
        self.policy.load_state_dict(torch.load(checkpoint_path))
        self.policy_old.load_state_dict(self.policy.state_dict())
        print(f"Model loaded from {checkpoint_path}")

# %%
# Memory
class Memory:
    def __init__(self):
        self.states = []
        self.actions = []
        self.logprobs = []
        self.rewards = []
        self.is_terminals = []

    def clear_memory(self):
        del self.states[:]
        del self.actions[:]
        del self.logprobs[:]
        del self.rewards[:]
        del self.is_terminals[:]

# %%
# Normalize state
def normalize_state(state):
    return (state - np.mean(state)) / (np.std(state) + 1e-8)

# %%
env_name = "LunarLander-v2"
env = gym.make(env_name)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

memory = Memory()
ppo = PPO(state_dim, action_dim)
# Out:
# /home/janak/Documents/Pytorch_CPU/venv/lib/python3.10/site-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /home/janak/Documents/Pytorch_CPU/venv/lib/python3.10/site-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
print_interval = 20
max_episodes = 5000  # Increase the number of episodes
max_timesteps = 300

running_reward = 0
avg_length = 0

# %%
for episode in range(1, max_episodes+1):
    state = env.reset()
    state = normalize_state(state)  # Normalize state
    for t in range(max_timesteps):
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        dist = ppo.policy_old.pi(state_tensor)
        action = dist.sample()

        next_state, reward, done, _ = env.step(action.item())
        next_state = normalize_state(next_state)  # Normalize next state

        memory.states.append(state_tensor)
        memory.actions.append(action)
        memory.logprobs.append(dist.log_prob(action))
        memory.rewards.append(reward)
        memory.is_terminals.append(done)

        state = next_state

        if done:
            break

    ppo.update(memory)
    memory.clear_memory()
    
    running_reward += reward
    avg_length += t

    if episode % print_interval == 0:
        avg_length = int(avg_length/print_interval)
        running_reward = int((running_reward/print_interval))

        print(f'Episode {episode} \t avg length: {avg_length} \t reward: {running_reward}')
        running_reward = 0
        avg_length = 0
    
    # if episode % 50 == 0:
    #     ppo.save(checkpoint_path)

env.close()
# Out:
# /home/janak/Documents/Pytorch_CPU/venv/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Episode 20 	 avg length: 112 	 reward: -100
# Episode 40 	 avg length: 138 	 reward: -100
# Episode 60 	 avg length: 175 	 reward: -88
# Episode 80 	 avg length: 171 	 reward: -95
# Episode 100 	 avg length: 184 	 reward: -80
# Episode 120 	 avg length: 224 	 reward: -50
# Episode 140 	 avg length: 133 	 reward: -90
# Episode 160 	 avg length: 175 	 reward: -65
# Episode 180 	 avg length: 186 	 reward: -64
# Episode 200 	 avg length: 216 	 reward: -44
# Episode 220 	 avg length: 196 	 reward: -54
# Episode 240 	 avg length: 219 	 reward: -58
# Episode 260 	 avg length: 257 	 reward: -35
# Episode 280 	 avg length: 252 	 reward: -29
# Episode 300 	 avg length: 229 	 reward: -34
# Episode 320 	 avg length: 253 	 reward: -34
# Episode 340 	 avg length: 275 	 reward: -30
# Episode 360 	 avg length: 192 	 reward: -65
# Episode 380 	 avg length: 279 	 reward: -14
# Episode 400 	 avg length: 222 	 reward: -55
# Episode 420 	 avg length: 255 	 reward: -30
# Episode 440 	 avg length: 220 	 reward: -44
# Episode 460 	 avg length: 278 	 reward: -15
# Episode 480 	 avg length: 268 	 reward: 0
# Episode 500 	 avg length: 261 	 reward: -29
# Episode 520 	 avg length: 291 	 reward: -9
# Episode 540 	 avg length: 274 	 reward: -45
# Episode 560 	 avg length: 213 	 reward: -65
# Episode 580 	 avg length: 292 	 reward: -11
# Episode 600 	 avg length: 238 	 reward: -55
# Episode 620 	 avg length: 262 	 reward: -45
# Episode 640 	 avg length: 275 	 reward: -15
# Episode 660 	 avg length: 220 	 reward: -74
# Episode 680 	 avg length: 235 	 reward: -20
# Episode 700 	 avg length: 268 	 reward: 4
# Episode 720 	 avg length: 189 	 reward: -4
# Episode 740 	 avg length: 140 	 reward: -50
# Episode 760 	 avg length: 256 	 reward: -19
# Episode 780 	 avg length: 282 	 reward: -15
# Episode 800 	 avg length: 281 	 reward: -9
# Episode 820 	 avg length: 278 	 reward: -15
# Episode 840 	 avg length: 262 	 reward: -32
# Episode 860 	 avg length: 264 	 reward: -19
# Episode 880 	 avg length: 251 	 reward: -31
# Episode 900 	 avg length: 237 	 reward: -34
# Episode 920 	 avg length: 270 	 reward: -22
# Episode 940 	 avg length: 253 	 reward: -30
# Episode 960 	 avg length: 290 	 reward: -10
# Episode 980 	 avg length: 285 	 reward: -18
# Episode 1000 	 avg length: 259 	 reward: -27
# Episode 1020 	 avg length: 275 	 reward: -16
# Episode 1040 	 avg length: 237 	 reward: -20
# Episode 1060 	 avg length: 202 	 reward: 16
# Episode 1080 	 avg length: 223 	 reward: 20
# Episode 1100 	 avg length: 174 	 reward: 15
# Episode 1120 	 avg length: 223 	 reward: 25
# Episode 1140 	 avg length: 201 	 reward: 9
# Episode 1160 	 avg length: 179 	 reward: -39
# Episode 1180 	 avg length: 187 	 reward: -5
# Episode 1200 	 avg length: 213 	 reward: -30
# Episode 1220 	 avg length: 201 	 reward: -34
# Episode 1240 	 avg length: 192 	 reward: -4
# Episode 1260 	 avg length: 253 	 reward: 10
# Episode 1280 	 avg length: 233 	 reward: 15
# Episode 1300 	 avg length: 170 	 reward: -14
# Episode 1320 	 avg length: 201 	 reward: -4
# Episode 1340 	 avg length: 257 	 reward: 9
# Episode 1360 	 avg length: 276 	 reward: 30
# Episode 1380 	 avg length: 290 	 reward: -9
# Episode 1400 	 avg length: 288 	 reward: -5
# Episode 1420 	 avg length: 287 	 reward: 5
# Episode 1440 	 avg length: 271 	 reward: -15
# Episode 1460 	 avg length: 269 	 reward: -9
# Episode 1480 	 avg length: 250 	 reward: 4
# Episode 1500 	 avg length: 237 	 reward: 39
# Episode 1520 	 avg length: 238 	 reward: 34
# Episode 1540 	 avg length: 236 	 reward: 34
# Episode 1560 	 avg length: 143 	 reward: -80
# Episode 1580 	 avg length: 209 	 reward: -44
# Episode 1600 	 avg length: 263 	 reward: -25
# Episode 1620 	 avg length: 277 	 reward: -15
# Episode 1640 	 avg length: 299 	 reward: -1
# Episode 1660 	 avg length: 277 	 reward: -15
# Episode 1680 	 avg length: 264 	 reward: -20
# Episode 1700 	 avg length: 293 	 reward: -4
# Episode 1720 	 avg length: 276 	 reward: -15
# Episode 1740 	 avg length: 293 	 reward: -4
# Episode 1760 	 avg length: 299 	 reward: 0
# Episode 1780 	 avg length: 299 	 reward: -1
# Episode 1800 	 avg length: 299 	 reward: 0
# Episode 1820 	 avg length: 299 	 reward: 0
# Episode 1840 	 avg length: 292 	 reward: -4
# Episode 1860 	 avg length: 299 	 reward: 0
# Episode 1880 	 avg length: 299 	 reward: 0
# Episode 1900 	 avg length: 299 	 reward: 0
# Episode 1920 	 avg length: 265 	 reward: -25
# Episode 1940 	 avg length: 267 	 reward: -9
# Episode 1960 	 avg length: 250 	 reward: -11
# Episode 1980 	 avg length: 260 	 reward: 19
# Episode 2000 	 avg length: 200 	 reward: -45
# Episode 2020 	 avg length: 212 	 reward: -35
# Episode 2040 	 avg length: 199 	 reward: -70
# Episode 2060 	 avg length: 150 	 reward: -84
# Episode 2080 	 avg length: 229 	 reward: -19
# Episode 2100 	 avg length: 264 	 reward: -15
# Episode 2120 	 avg length: 275 	 reward: 4
# Episode 2140 	 avg length: 239 	 reward: -35
# Episode 2160 	 avg length: 268 	 reward: -25
# Episode 2180 	 avg length: 185 	 reward: -55
# Episode 2200 	 avg length: 248 	 reward: -18
# Episode 2220 	 avg length: 190 	 reward: -56
# Episode 2240 	 avg length: 239 	 reward: -4
# Episode 2260 	 avg length: 275 	 reward: -18
# Episode 2280 	 avg length: 259 	 reward: -27
# Episode 2300 	 avg length: 242 	 reward: -10
# Episode 2320 	 avg length: 231 	 reward: -15
# Episode 2340 	 avg length: 262 	 reward: -14
# Episode 2360 	 avg length: 252 	 reward: -18
# Episode 2380 	 avg length: 290 	 reward: -5
# Episode 2400 	 avg length: 289 	 reward: -12
# Episode 2420 	 avg length: 296 	 reward: -4
# Episode 2440 	 avg length: 292 	 reward: -4
# Episode 2460 	 avg length: 293 	 reward: -4
# Episode 2480 	 avg length: 275 	 reward: -20
# Episode 2500 	 avg length: 253 	 reward: -35
# Episode 2520 	 avg length: 266 	 reward: -24
# Episode 2540 	 avg length: 299 	 reward: 2
# Episode 2560 	 avg length: 256 	 reward: -30
# Episode 2580 	 avg length: 273 	 reward: -14
# Episode 2600 	 avg length: 290 	 reward: -5
# Episode 2620 	 avg length: 299 	 reward: 0
# Episode 2640 	 avg length: 260 	 reward: -20
# Episode 2660 	 avg length: 262 	 reward: -21
# Episode 2680 	 avg length: 268 	 reward: 15
# Episode 2700 	 avg length: 248 	 reward: 40
# Episode 2720 	 avg length: 210 	 reward: 15
# Episode 2740 	 avg length: 244 	 reward: 50
# Episode 2760 	 avg length: 216 	 reward: 65
# Episode 2780 	 avg length: 225 	 reward: 34
# Episode 2800 	 avg length: 216 	 reward: 49
# Episode 2820 	 avg length: 190 	 reward: 30
# Episode 2840 	 avg length: 223 	 reward: 24
# Episode 2860 	 avg length: 262 	 reward: 29
# Episode 2880 	 avg length: 223 	 reward: 35
# Episode 2900 	 avg length: 228 	 reward: 59
# Episode 2920 	 avg length: 211 	 reward: 55
# Episode 2940 	 avg length: 160 	 reward: 10
# Episode 2960 	 avg length: 201 	 reward: 14
# Episode 2980 	 avg length: 182 	 reward: -4
# Episode 3000 	 avg length: 204 	 reward: -19
# Episode 3020 	 avg length: 205 	 reward: 49
# Episode 3040 	 avg length: 233 	 reward: 49
# Episode 3060 	 avg length: 205 	 reward: 0
# Episode 3080 	 avg length: 241 	 reward: -9
# Episode 3100 	 avg length: 230 	 reward: -15
# Episode 3120 	 avg length: 194 	 reward: -35
# Episode 3140 	 avg length: 158 	 reward: -59
# Episode 3160 	 avg length: 122 	 reward: -84
# Episode 3180 	 avg length: 151 	 reward: -60
# Episode 3200 	 avg length: 173 	 reward: -25
# Episode 3220 	 avg length: 148 	 reward: -30
# Episode 3240 	 avg length: 205 	 reward: 4
# Episode 3260 	 avg length: 159 	 reward: -30
# Episode 3280 	 avg length: 200 	 reward: 0
# Episode 3300 	 avg length: 220 	 reward: 1
# Episode 3320 	 avg length: 205 	 reward: -8
# Episode 3340 	 avg length: 184 	 reward: -44
# Episode 3360 	 avg length: 201 	 reward: 29
# Episode 3380 	 avg length: 211 	 reward: 29
# Episode 3400 	 avg length: 181 	 reward: -10
# Episode 3420 	 avg length: 202 	 reward: 19
# Episode 3440 	 avg length: 148 	 reward: -39
# Episode 3460 	 avg length: 192 	 reward: 14
# Episode 3480 	 avg length: 153 	 reward: -24
# Episode 3500 	 avg length: 243 	 reward: 0
# Episode 3520 	 avg length: 238 	 reward: -35
# Episode 3540 	 avg length: 255 	 reward: -25
# Episode 3560 	 avg length: 213 	 reward: -44
# Episode 3580 	 avg length: 246 	 reward: -30
# Episode 3600 	 avg length: 240 	 reward: -30
# Episode 3620 	 avg length: 244 	 reward: -29
# Episode 3640 	 avg length: 271 	 reward: -15
# Episode 3660 	 avg length: 252 	 reward: 0
# Episode 3680 	 avg length: 217 	 reward: -13
# Episode 3700 	 avg length: 255 	 reward: -22
# Episode 3720 	 avg length: 281 	 reward: -21
# Episode 3740 	 avg length: 266 	 reward: -20
# Episode 3760 	 avg length: 274 	 reward: 4
# Episode 3780 	 avg length: 230 	 reward: -40
# Episode 3800 	 avg length: 244 	 reward: 35
# Episode 3820 	 avg length: 220 	 reward: 8
# Episode 3840 	 avg length: 229 	 reward: 49
# Episode 3860 	 avg length: 193 	 reward: 50
# Episode 3880 	 avg length: 219 	 reward: 50
# Episode 3900 	 avg length: 243 	 reward: 64
# Episode 3920 	 avg length: 177 	 reward: -15
# Episode 3940 	 avg length: 217 	 reward: -4
# Episode 3960 	 avg length: 231 	 reward: -30
# Episode 3980 	 avg length: 228 	 reward: 5
# Episode 4000 	 avg length: 251 	 reward: 5
# Episode 4020 	 avg length: 235 	 reward: 0
# Episode 4040 	 avg length: 235 	 reward: -9
# Episode 4060 	 avg length: 241 	 reward: 20
# Episode 4080 	 avg length: 234 	 reward: 40
# Episode 4100 	 avg length: 257 	 reward: 39
# Episode 4120 	 avg length: 256 	 reward: 36
# Episode 4140 	 avg length: 272 	 reward: 20
# Episode 4160 	 avg length: 274 	 reward: -9
# Episode 4180 	 avg length: 265 	 reward: 0
# Episode 4200 	 avg length: 222 	 reward: -29
# Episode 4220 	 avg length: 269 	 reward: -5
# Episode 4240 	 avg length: 272 	 reward: 15
# Episode 4260 	 avg length: 276 	 reward: -5
# Episode 4280 	 avg length: 296 	 reward: 9
# Episode 4300 	 avg length: 269 	 reward: -5
# Episode 4320 	 avg length: 261 	 reward: 0
# Episode 4340 	 avg length: 292 	 reward: 20
# Episode 4360 	 avg length: 250 	 reward: -15
# Episode 4380 	 avg length: 280 	 reward: -11
# Episode 4400 	 avg length: 278 	 reward: 9
# Episode 4420 	 avg length: 232 	 reward: 9
# Episode 4440 	 avg length: 246 	 reward: 10
# Episode 4460 	 avg length: 249 	 reward: 25
# Episode 4480 	 avg length: 241 	 reward: 9
# Episode 4500 	 avg length: 271 	 reward: 20
# Episode 4520 	 avg length: 246 	 reward: -40
# Episode 4540 	 avg length: 260 	 reward: -4
# Episode 4560 	 avg length: 261 	 reward: 0
# Episode 4580 	 avg length: 225 	 reward: -8
# Episode 4600 	 avg length: 248 	 reward: 49
# Episode 4620 	 avg length: 272 	 reward: 20
# Episode 4640 	 avg length: 290 	 reward: 20
# Episode 4660 	 avg length: 277 	 reward: -4
# Episode 4680 	 avg length: 282 	 reward: 35
# Episode 4700 	 avg length: 286 	 reward: 30
# Episode 4720 	 avg length: 262 	 reward: 15
# Episode 4740 	 avg length: 219 	 reward: 15
# Episode 4760 	 avg length: 237 	 reward: 40
# Episode 4780 	 avg length: 236 	 reward: 0
# Episode 4800 	 avg length: 183 	 reward: -24
# Episode 4820 	 avg length: 211 	 reward: 0
# Episode 4840 	 avg length: 205 	 reward: -9
# Episode 4860 	 avg length: 209 	 reward: 19
# Episode 4880 	 avg length: 179 	 reward: 8
# Episode 4900 	 avg length: 224 	 reward: 28
# Episode 4920 	 avg length: 208 	 reward: 19
# Episode 4940 	 avg length: 210 	 reward: 4
# Episode 4960 	 avg length: 227 	 reward: -10
# Episode 4980 	 avg length: 257 	 reward: 29
# Episode 5000 	 avg length: 198 	 reward: -10

# %%
path = 'models/ppo_more_lunar_lander.pth'

# %%
ppo.save(path)
# Out:
# Model saved to models/ppo_more_lunar_lander.pth
