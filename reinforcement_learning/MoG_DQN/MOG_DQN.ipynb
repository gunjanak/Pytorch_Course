# %% [markdown]
# #Install and Import

# %%
# !pip install gym==0.25.2
# !pip install swig
# !pip install gym[box2d]
# Out:
# Requirement already satisfied: gym==0.25.2 in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.25.2) (0.0.8)
# Requirement already satisfied: swig in /usr/local/lib/python3.10/dist-packages (4.2.1)
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.3.5)
# Requirement already satisfied: pygame==2.1.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.1.0)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (4.2.1)

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os

# %% [markdown]
# #Changing Dir

# %%
# PATH = '/content/drive/MyDrive/Pytorch/rl/MOG_DQN'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# os.chdir(PATH)

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Pytorch/rl/MOG_DQN

# %% [markdown]
# #Env

# %%
# Initialize the Lunar Lander environment
env = gym.make('LunarLander-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %% [markdown]
# #Creating Model

# %%
class GaussianMixtureModel(nn.Module):
    def __init__(self, state_dim, action_dim,num_components,hidden_dim=256):
        super(GaussianMixtureModel, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.num_components = num_components

        self.fc1 = nn.Linear(state_dim,hidden_dim)
        self.fc2 = nn.Linear(hidden_dim,hidden_dim)

        #output action_dim * num_components   (4*5)
        self.mean = nn.Linear(hidden_dim, action_dim * num_components)
        self.log_var = nn.Linear(hidden_dim, action_dim * num_components)
        self.logits = nn.Linear(hidden_dim, action_dim * num_components)

    def forward(self, state):

        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        #mean is reshaped from (1,20) to (1,4,5)and so is log_var and logits
        mean = self.mean(x).view(-1, self.action_dim, self.num_components)
        log_var = self.log_var(x).view(-1, self.action_dim, self.num_components)
        log_var = torch.clamp(log_var, -10, 10)  # Clipping log variance for stability
        logits = self.logits(x).view(-1, self.action_dim, self.num_components)
        return mean, log_var, logits

    def get_distribution(self, state):
        """
        mean represents the expected value of the distribution.
        log_var represents the logarithm of the variance of the distribution.
        Taking the exponential of log_var yields the variance.
        logits represent the unnormalized log probabilities of each action.
        Softmax is applied to logits to convert them into a probability distribution.
        This function encapsulates the logic of computing the distribution parameters
        and is useful for sampling actions from the distribution or
        computing probabilities of actions given states during training or
        inference in reinforcement learning algorithms.
        """
        mean, log_var, logits = self.forward(state)
        return mean, torch.exp(log_var), torch.softmax(logits, dim=-1)

# %%
# Experience replay buffer
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = []
        self.capacity = capacity

    def push(self, experience):
        if len(self.buffer) >= self.capacity:
            self.buffer.pop(0)
        self.buffer.append(experience)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        return [self.buffer[idx] for idx in indices]

# %% [markdown]
# #Define Functions

# %%
def compute_loss(mean, var, logits, target):
    # a Normal distribution object m is created using the provided mean and var tensors.
    #This distribution will be used to calculate the log probabilities of the target values.

    m = torch.distributions.Normal(mean, var)


    #target.unsqueeze(-1) adds an extra dimension to target to make it compatible for broadcasting with mean.
    #expand_as(mean) expands the target tensor to the same shape as mean.
    #m.log_prob(target) computes the log probability of target under the normal distribution m.
    #The result is a tensor of log probabilities with the same shape as mean.
    log_prob = m.log_prob(target.unsqueeze(-1).expand_as(mean))
    # print(f"log_prob: {log_prob.shape}")

    #torch.sum(log_prob, dim=-2) sums the log probabilities along the second last dimension,
    #aggregating the contributions across different dimensions of mean.
    #torch.log(logits + 1e-10) adds the log of logits to the summed log probabilities.
    # The 1e-10 is a small epsilon value added to avoid taking the logarithm of zero,
    # which would result in numerical instability.
    #The resulting log_prob tensor now incorporates both the log probabilities
    #of the target values under the normal distributions and the log of the class logits.
    log_prob = torch.sum(log_prob, dim=-2) + torch.log(logits + 1e-10)  # Adding epsilon for numerical stability
    # print(f"log_prob: {log_prob.shape}")

    #torch.logsumexp(log_prob, dim=-1) computes the log-sum-exp across the last dimension of log_prob.
    # This operation is numerically stable and combines the probabilities in a way that prevents underflow or overflow.
    #The negative sign indicates that we are converting the log-sum-exp to a negative log likelihood.
    #.mean() computes the average loss over the batch.
    loss = -torch.logsumexp(log_prob, dim=-1).mean()
    # print(f"loss: {loss.shape}")
    return loss

# %%
def save_checkpoint(state, filename='checkpoint.pth'):
    torch.save(state, filename)

# %%
def load_checkpoint(filename='checkpoint.pth', map_location=None):
    if map_location:
        return torch.load(filename, map_location=map_location)
    return torch.load(filename)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# #Hyperparameters

# %%
# Hyperparameters
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
hidden_dim = 128
num_components = 5
learning_rate = 0.0005
num_episodes = 2000
gamma = 0.99
batch_size = 64
buffer_capacity = 10000
target_update_freq = 5

# %%
# Exploration parameters
epsilon_start = 1.0
epsilon_end = 0.01
epsilon_decay = 0.995

# %% [markdown]
# #Initialize

# %%
buffer = ReplayBuffer(buffer_capacity)

# %%
# Initialize model and target model
model = GaussianMixtureModel(state_dim, action_dim, num_components,hidden_dim)
target_model = GaussianMixtureModel(state_dim, action_dim, num_components,hidden_dim)

# %%
# Move the model to the chosen device
model.to(device)
target_model.to(device)
# Out:
# GaussianMixtureModel(
#   (fc1): Linear(in_features=8, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (mean): Linear(in_features=128, out_features=20, bias=True)
#   (log_var): Linear(in_features=128, out_features=20, bias=True)
#   (logits): Linear(in_features=128, out_features=20, bias=True)
# )

# %%
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
checkpoint_path = 'mog_dqn.pth'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
try:
    map_location = torch.device('cpu') if not torch.cuda.is_available() else None
    checkpoint = load_checkpoint(checkpoint_path, map_location=map_location)
    model.load_state_dict(checkpoint['main_net_state_dict'])
    target_model.load_state_dict(checkpoint['target_net_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epsilon = checkpoint['epsilon']
    start_episode = checkpoint['episode'] + 1
    print(f"Loaded checkpoint from episode {start_episode}")
except FileNotFoundError:
    print("No checkpoint found, starting from scratch.")
# Out:
# No checkpoint found, starting from scratch.

# %%
target_model.load_state_dict(model.state_dict())
target_model.eval()
# Out:
# GaussianMixtureModel(
#   (fc1): Linear(in_features=8, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (mean): Linear(in_features=128, out_features=20, bias=True)
#   (log_var): Linear(in_features=128, out_features=20, bias=True)
#   (logits): Linear(in_features=128, out_features=20, bias=True)
# )

# %% [markdown]
# #Train

# %%
episode_rewards = []

# %%
# Training loop
epsilon = epsilon_start
for episode in range(num_episodes):
    #reset the environment
    state = env.reset()

    #reset the total reward for the episode
    total_reward = 0

    #reset the timer
    for t in range(1000):
        # Convert state to tensor
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)

        #pass the state_tensor to the model and get mean, var and logits
        #the shape of mean is (1,action_dim,num_components)  (1,4,5)
        #the shape of var is (1,action_dim,num_components)  (1,4,5)
        #the shape of logits is (1,action_dim,num_components)  (1,4,5)
        mean, var, logits = model.get_distribution(state_tensor)

        #the mean(dim=-1) function calculates the mean across the last dimension of the tensor,
        #and softmax(dim=-1) applies the softmax function across the last dimension.
        #The shape of action_probs is (1,4)
        #Each value representating the probability of taking each action
        action_probs = mean.mean(dim=-1).softmax(dim=-1).cpu().detach().numpy()


        # Handle NaN values in action_probs
        if np.isnan(action_probs).any():
            action_probs = np.nan_to_num(action_probs, nan=1.0/action_dim)
            action_probs /= action_probs.sum()  # Re-normalize to ensure it's a valid probability distribution

        # ε-greedy exploration strategy
        if np.random.rand() < epsilon:
            #Take a random action
            action = np.random.choice(action_dim)
        else:
            #Take the action with the highest probability
            action = np.argmax(action_probs[0])

        #next_state, reward, done after taking the action
        next_state, reward, done, _ = env.step(action)

        #Put these inside replay buffer
        buffer.push((state, action, reward, next_state, done))

        #set next_state as current state
        state = next_state

        #adding to total reward
        total_reward += reward

        #checking the buffer size
        if len(buffer.buffer) >= batch_size:
            #Sample a batch of experiences
            batch = buffer.sample(batch_size)
            #Each tuple represents a single transition in the environment and
            #consists of (state, action, reward, next_state, done).
            #Using the zip(*batch) operation allows you to unpack these
            #transitions into separate tuples for states, actions, rewards, next_states, and dones.
            states, actions, rewards, next_states, dones = zip(*batch)

            #converting to tensor
            states_tensor = torch.tensor(states, dtype=torch.float32).to(device)
            actions_tensor = torch.tensor(actions, dtype=torch.long).to(device)
            rewards_tensor = torch.tensor(rewards, dtype=torch.float32).to(device)
            next_states_tensor = torch.tensor(next_states, dtype=torch.float32).to(device)
            dones_tensor = torch.tensor(dones, dtype=torch.float32).to(device)

            #The shape of states_tensor is (batch_size,observation_space) (64,8)
            #mean represents the expected value of the distribution.
            #log_var represents the logarithm of the variance of the distribution.
            #Taking the exponential of log_var yields the variance.
            #logits represent the unnormalized log probabilities of each action.
            #Softmax is applied to logits to convert them into a probability distribution.
            mean, var, logits = model.get_distribution(states_tensor)

            #torch.no_grad() is a context manager in PyTorch that is used to disable gradient calculation.
            #This is useful when you are performing inference (making predictions)
            #and do not need the gradients for backpropagation, which helps save memory and computation.
            with torch.no_grad():
                next_mean, next_var, next_logits = target_model.get_distribution(next_states_tensor)

            target = rewards_tensor + gamma * torch.max(next_mean.mean(dim=-1), dim=1).values * (1 - dones_tensor)


            #Extracts the mean and var as guided by the actions
            mean = mean.gather(1, actions_tensor.unsqueeze(-1).unsqueeze(-1).expand(-1, -1, num_components)).squeeze(1)
            var = var.gather(1, actions_tensor.unsqueeze(-1).unsqueeze(-1).expand(-1, -1, num_components)).squeeze(1)
            logits = logits.gather(1, actions_tensor.unsqueeze(-1).unsqueeze(-1).expand(-1, -1, num_components)).squeeze(1)

            loss = compute_loss(mean, var, logits, target)

            optimizer.zero_grad()
            loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            optimizer.step()

        if done:
            break

    # Decay epsilon
    epsilon = max(epsilon_end, epsilon_decay * epsilon)

    episode_rewards.append(total_reward)
    # Update the target network
    if episode % target_update_freq == 0:
        target_model.load_state_dict(model.state_dict())

    print(f"Episode {episode}, Total Reward: {total_reward}")


    if episode % 50 == 0:
        save_checkpoint({
            'episode': episode,
            'main_net_state_dict': model.state_dict(),
            'target_net_state_dict': target_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epsilon': epsilon
        }, checkpoint_path)
        print(f"Checkpoint saved at episode {episode}")


    if(sum(episode_rewards[-5:])>1000):
      print(sum(episode_rewards[-5:])>1000)
      print("Training done")
      save_checkpoint({
            'episode': episode,
            'main_net_state_dict': model.state_dict(),
            'target_net_state_dict': target_model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'epsilon': epsilon
        }, checkpoint_path)
      print(f"Checkpoint saved at episode {episode}")
      break
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/utils/passive_env_checker.py:241: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# <ipython-input-23-94b2b0de2e75>:64: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:274.)
#   states_tensor = torch.tensor(states, dtype=torch.float32).to(device)
# Episode 0, Total Reward: -328.7246920612579
# Checkpoint saved at episode 0
# Episode 1, Total Reward: -15.642152556351007
# Episode 2, Total Reward: -67.96524373670869
# Episode 3, Total Reward: -127.91584412776939
# Episode 4, Total Reward: -243.46313082528516
# Episode 5, Total Reward: -101.97163217847715
# Episode 6, Total Reward: -86.51404279548872
# Episode 7, Total Reward: -63.26510193873946
# Episode 8, Total Reward: -232.60392602898534
# Episode 9, Total Reward: -119.47578877260489
# Episode 10, Total Reward: -277.9343961736424
# Episode 11, Total Reward: -4.237565077275136
# Episode 12, Total Reward: -358.0058036030391
# Episode 13, Total Reward: -128.2873716616307
# Episode 14, Total Reward: -177.98357675876613
# Episode 15, Total Reward: -202.6590407152305
# Episode 16, Total Reward: -208.3858292636416
# Episode 17, Total Reward: -152.24608437087784
# Episode 18, Total Reward: -126.57687559199424
# Episode 19, Total Reward: -59.27290176340579
# Episode 20, Total Reward: -89.33296543204973
# Episode 21, Total Reward: -76.35794138876945
# Episode 22, Total Reward: -203.94419765717396
# Episode 23, Total Reward: -402.36269869138374
# Episode 24, Total Reward: -159.48979322584802
# Episode 25, Total Reward: -246.91501703023974
# Episode 26, Total Reward: -132.26025332664292
# Episode 27, Total Reward: -296.8100703742952
# Episode 28, Total Reward: -122.36282555528852
# Episode 29, Total Reward: -43.198098366353925
# Episode 30, Total Reward: -153.7368533489033
# Episode 31, Total Reward: -91.98016846619541
# Episode 32, Total Reward: -85.4098647506079
# Episode 33, Total Reward: -150.35371916068942
# Episode 34, Total Reward: -58.403245342659716
# Episode 35, Total Reward: -124.20234347725085
# Episode 36, Total Reward: -242.1744065706553
# Episode 37, Total Reward: -106.30237082698893
# Episode 38, Total Reward: -293.7821132004842
# Episode 39, Total Reward: -177.35903775524963
# Episode 40, Total Reward: -325.6938453876305
# Episode 41, Total Reward: -111.66762650189118
# Episode 42, Total Reward: -123.88531920572167
# Episode 43, Total Reward: -229.12561394571262
# Episode 44, Total Reward: -98.66488443232157
# Episode 45, Total Reward: -249.67412512531243
# Episode 46, Total Reward: -119.75536241970605
# Episode 47, Total Reward: -136.27083007759438
# Episode 48, Total Reward: -128.27586767973287
# Episode 49, Total Reward: -184.34720401950128
# Episode 50, Total Reward: -182.22942303650268
# Checkpoint saved at episode 50
# Episode 51, Total Reward: -249.76106749693753
# Episode 52, Total Reward: -74.33426149052035
# Episode 53, Total Reward: -136.14131601143674
# Episode 54, Total Reward: -145.01204618768557
# Episode 55, Total Reward: -87.4720614176683
# Episode 56, Total Reward: -193.93211138766407
# Episode 57, Total Reward: -72.20052805375772
# Episode 58, Total Reward: -66.7719193547826
# Episode 59, Total Reward: -59.17648524044564
# Episode 60, Total Reward: -80.10763442710304
# Episode 61, Total Reward: -148.30465285534603
# Episode 62, Total Reward: -201.64690145650422
# Episode 63, Total Reward: -68.65703088784205
# Episode 64, Total Reward: -118.34802379599438
# Episode 65, Total Reward: -108.03884815284044
# Episode 66, Total Reward: -81.88048775031577
# Episode 67, Total Reward: -152.20679032336471
# Episode 68, Total Reward: -144.16149305123605
# Episode 69, Total Reward: -50.5152017285951
# Episode 70, Total Reward: -81.26798443823633
# Episode 71, Total Reward: -153.82949350582476
# Episode 72, Total Reward: -97.41301024255216
# Episode 73, Total Reward: -232.2610610522747
# Episode 74, Total Reward: -248.62362244605026
# Episode 75, Total Reward: -78.6764720399739
# Episode 76, Total Reward: -126.63403014028661
# Episode 77, Total Reward: -151.86425955720844
# Episode 78, Total Reward: -36.85524959790679
# Episode 79, Total Reward: -77.4250749210681
# Episode 80, Total Reward: -60.387638713740365
# Episode 81, Total Reward: -12.111281262451797
# Episode 82, Total Reward: -109.17901514832614
# Episode 83, Total Reward: -68.18525689188245
# Episode 84, Total Reward: -37.69338073094838
# Episode 85, Total Reward: -128.0474190785793
# Episode 86, Total Reward: -237.07543080265629
# Episode 87, Total Reward: -97.64830558596685
# Episode 88, Total Reward: -49.11770453232383
# Episode 89, Total Reward: -135.5827762726095
# Episode 90, Total Reward: -173.68370963548367
# Episode 91, Total Reward: -115.13944527580006
# Episode 92, Total Reward: -236.02054797523172
# Episode 93, Total Reward: -137.8372772730559
# Episode 94, Total Reward: -241.54909675601874
# Episode 95, Total Reward: -4.8364079434384735
# Episode 96, Total Reward: -77.88666031301312
# Episode 97, Total Reward: -36.64430043763534
# Episode 98, Total Reward: -89.94768649592487
# Episode 99, Total Reward: -18.44274193389903
# Episode 100, Total Reward: -31.19916107525688
# Checkpoint saved at episode 100
# Episode 101, Total Reward: -216.00924145428485
# Episode 102, Total Reward: -151.56097446376344
# Episode 103, Total Reward: -139.4528569633155
# Episode 104, Total Reward: -80.50208066492297
# Episode 105, Total Reward: -198.00603644406596
# Episode 106, Total Reward: -15.464396304839
# Episode 107, Total Reward: -68.55569214615687
# Episode 108, Total Reward: -100.28561169829979
# Episode 109, Total Reward: -46.28361956982199
# Episode 110, Total Reward: -36.34273926812546
# Episode 111, Total Reward: -35.2701338186405
# Episode 112, Total Reward: -53.602089601079896
# Episode 113, Total Reward: -5.218610620093642
# Episode 114, Total Reward: -160.9708611232012
# Episode 115, Total Reward: -226.62880241840065
# Episode 116, Total Reward: -161.1016471162091
# Episode 117, Total Reward: -146.3018795080307
# Episode 118, Total Reward: -106.32383385941773
# Episode 119, Total Reward: -103.45532838525538
# Episode 120, Total Reward: -20.96353032998364
# Episode 121, Total Reward: -439.789837676822
# Episode 122, Total Reward: -23.818062647677145
# Episode 123, Total Reward: -140.26260246911846
# Episode 124, Total Reward: -72.26546099186557
# Episode 125, Total Reward: -7.062916596671371
# Episode 126, Total Reward: -120.99938479725105
# Episode 127, Total Reward: -223.96179463931747
# Episode 128, Total Reward: -91.89299514598551
# Episode 129, Total Reward: -75.4346388208146
# Episode 130, Total Reward: -111.84562570353926
# Episode 131, Total Reward: -91.43844962560985
# Episode 132, Total Reward: -81.7019657360406
# Episode 133, Total Reward: -143.14031853243284
# Episode 134, Total Reward: 34.00521281959266
# Episode 135, Total Reward: -101.59660341658808
# Episode 136, Total Reward: -95.35459855508009
# Episode 137, Total Reward: -116.11104611473971
# Episode 138, Total Reward: -22.43481251235939
# Episode 139, Total Reward: -71.9146216852628
# Episode 140, Total Reward: 32.839234492316045
# Episode 141, Total Reward: -166.5385412954646
# Episode 142, Total Reward: -89.45540913372604
# Episode 143, Total Reward: -104.19196505996901
# Episode 144, Total Reward: -74.33006040320406
# Episode 145, Total Reward: -176.20825670609239
# Episode 146, Total Reward: -109.98211289984212
# Episode 147, Total Reward: -123.15425750665416
# Episode 148, Total Reward: -114.04362632608708
# Episode 149, Total Reward: -208.49872009522227
# Episode 150, Total Reward: -80.80776100064165
# Checkpoint saved at episode 150
# Episode 151, Total Reward: -4.964252302045651
# Episode 152, Total Reward: -114.95071791699728
# Episode 153, Total Reward: -10.405839957114082
# Episode 154, Total Reward: -32.07590997446245
# Episode 155, Total Reward: -60.844341016334965
# Episode 156, Total Reward: -213.4165304381965
# Episode 157, Total Reward: -35.07105460048378
# Episode 158, Total Reward: -47.68858227981762
# Episode 159, Total Reward: -109.92861213344996
# Episode 160, Total Reward: -96.64815310123798
# Episode 161, Total Reward: -96.4919937367923
# Episode 162, Total Reward: -131.89741835491122
# Episode 163, Total Reward: 20.611671555796548
# Episode 164, Total Reward: 73.68714523587643
# Episode 165, Total Reward: -53.076125253848375
# Episode 166, Total Reward: 1.1329718005642633
# Episode 167, Total Reward: 12.083350180210417
# Episode 168, Total Reward: -29.541928956805307
# Episode 169, Total Reward: -180.94785425548594
# Episode 170, Total Reward: 51.02879041573796
# Episode 171, Total Reward: -243.64255589284605
# Episode 172, Total Reward: 39.46162054822062
# Episode 173, Total Reward: -77.4204940165319
# Episode 174, Total Reward: -14.772261094036665
# Episode 175, Total Reward: -106.37817405832008
# Episode 176, Total Reward: -115.28799543049684
# Episode 177, Total Reward: -58.368154749144075
# Episode 178, Total Reward: -83.39496179530124
# Episode 179, Total Reward: -78.74170004987108
# Episode 180, Total Reward: -270.66844366671
# Episode 181, Total Reward: 62.23408108768484
# Episode 182, Total Reward: -49.637122083860675
# Episode 183, Total Reward: -80.63707780347805
# Episode 184, Total Reward: -42.480839316426014
# Episode 185, Total Reward: -17.259999248889727
# Episode 186, Total Reward: -22.299969411357992
# Episode 187, Total Reward: -192.47239787974257
# Episode 188, Total Reward: 43.34002125904914
# Episode 189, Total Reward: -210.66698700465554
# Episode 190, Total Reward: -68.2386578097964
# Episode 191, Total Reward: -212.21508242896624
# Episode 192, Total Reward: 90.01746388683456
# Episode 193, Total Reward: -212.09165327163538
# Episode 194, Total Reward: -49.77190266736436
# Episode 195, Total Reward: -48.10042996024218
# Episode 196, Total Reward: -30.456997570901464
# Episode 197, Total Reward: -54.011586688160406
# Episode 198, Total Reward: -11.46130699610309
# Episode 199, Total Reward: -97.48451525212573
# Episode 200, Total Reward: -89.54723689786248
# Checkpoint saved at episode 200
# Episode 201, Total Reward: -78.84182307741204
# Episode 202, Total Reward: -13.074887509268606
# Episode 203, Total Reward: -42.715255500639344
# Episode 204, Total Reward: -214.8891053118731
# Episode 205, Total Reward: 15.357837359196239
# Episode 206, Total Reward: -11.206719921881557
# Episode 207, Total Reward: -192.611419490483
# Episode 208, Total Reward: 13.357021961449021
# Episode 209, Total Reward: -229.3840883174995
# Episode 210, Total Reward: -43.889615833955006
# Episode 211, Total Reward: 12.418673243240548
# Episode 212, Total Reward: 67.14807576032035
# Episode 213, Total Reward: 64.25634812631706
# Episode 214, Total Reward: 7.628655822684195
# Episode 215, Total Reward: -59.694876312175566
# Episode 216, Total Reward: -20.961104360851195
# Episode 217, Total Reward: -105.87630495189964
# Episode 218, Total Reward: 75.75650351294429
# Episode 219, Total Reward: -26.940440085785028
# Episode 220, Total Reward: -15.08786602649485
# Episode 221, Total Reward: -239.52186884486196
# Episode 222, Total Reward: -10.325349302290533
# Episode 223, Total Reward: -1.967092514462891
# Episode 224, Total Reward: -63.43871253073689
# Episode 225, Total Reward: -113.82790364288641
# Episode 226, Total Reward: 88.1933397616192
# Episode 227, Total Reward: -223.38038229068968
# Episode 228, Total Reward: -84.11080968713534
# Episode 229, Total Reward: 81.1949989737273
# Episode 230, Total Reward: -230.4636100223326
# Episode 231, Total Reward: 104.53851665328224
# Episode 232, Total Reward: -89.9724006937608
# Episode 233, Total Reward: -41.74507205969341
# Episode 234, Total Reward: -79.82422683369849
# Episode 235, Total Reward: 48.68759988820268
# Episode 236, Total Reward: -108.014164914172
# Episode 237, Total Reward: -76.36365527580676
# Episode 238, Total Reward: -92.83788682504714
# Episode 239, Total Reward: 105.25889754289807
# Episode 240, Total Reward: -43.44585090936968
# Episode 241, Total Reward: 120.17359188352584
# Episode 242, Total Reward: -164.93927228800482
# Episode 243, Total Reward: -185.3678132729896
# Episode 244, Total Reward: -210.82248740795126
# Episode 245, Total Reward: 59.68391805333442
# Episode 246, Total Reward: -49.13904610293005
# Episode 247, Total Reward: 186.46321689848457
# Episode 248, Total Reward: 112.98684049367492
# Episode 249, Total Reward: -93.17689171297842
# Episode 250, Total Reward: -38.80227680734987
# Checkpoint saved at episode 250
# Episode 251, Total Reward: -211.20451812558227
# Episode 252, Total Reward: -208.77523478791258
# Episode 253, Total Reward: -113.04314736331335
# Episode 254, Total Reward: 3.844103867371018
# Episode 255, Total Reward: -27.34381363146872
# Episode 256, Total Reward: -11.500079892220896
# Episode 257, Total Reward: -37.32528860471518
# Episode 258, Total Reward: -18.007222239767998
# Episode 259, Total Reward: -163.49561225896844
# Episode 260, Total Reward: 87.39204282914433
# Episode 261, Total Reward: 148.93564039953088
# Episode 262, Total Reward: -216.7847995093893
# Episode 263, Total Reward: -198.86547082022054
# Episode 264, Total Reward: -243.269615257473
# Episode 265, Total Reward: -274.40792675796166
# Episode 266, Total Reward: -144.9648291732754
# Episode 267, Total Reward: -162.5525809941161
# Episode 268, Total Reward: -60.05321841291663
# Episode 269, Total Reward: -271.5547675109136
# Episode 270, Total Reward: -191.41030831494248
# Episode 271, Total Reward: -49.06554084448098
# Episode 272, Total Reward: -31.17019877187728
# Episode 273, Total Reward: 234.46636407804905
# Episode 274, Total Reward: -63.28188342076069
# Episode 275, Total Reward: -226.0080949197257
# Episode 276, Total Reward: 131.20247331863143
# Episode 277, Total Reward: -49.155151820521745
# Episode 278, Total Reward: -12.525387398720127
# Episode 279, Total Reward: -40.80398013728555
# Episode 280, Total Reward: -101.02188844612438
# Episode 281, Total Reward: 153.6678561364632
# Episode 282, Total Reward: -181.35872039776345
# Episode 283, Total Reward: -157.20928830340486
# Episode 284, Total Reward: -71.6672810122999
# Episode 285, Total Reward: 144.1181137992904
# Episode 286, Total Reward: 70.67440352670911
# Episode 287, Total Reward: -53.295524771349505
# Episode 288, Total Reward: -47.42396789466207
# Episode 289, Total Reward: -160.1559312026571
# Episode 290, Total Reward: -65.9797250001559
# Episode 291, Total Reward: -83.3233955750437
# Episode 292, Total Reward: 115.14249102861544
# Episode 293, Total Reward: 10.323303975359565
# Episode 294, Total Reward: 115.61124670301805
# Episode 295, Total Reward: -47.76552429327893
# Episode 296, Total Reward: 14.479314007707988
# Episode 297, Total Reward: -29.75852942376153
# Episode 298, Total Reward: 101.05000942074514
# Episode 299, Total Reward: -106.49861038378259
# Episode 300, Total Reward: 224.7951351723496
# Checkpoint saved at episode 300
# Episode 301, Total Reward: -104.07046030353679
# Episode 302, Total Reward: 70.70551981003112
# Episode 303, Total Reward: 166.3314643017172
# Episode 304, Total Reward: -57.833753082498475
# Episode 305, Total Reward: -34.79026551457136
# Episode 306, Total Reward: -77.25936305002881
# Episode 307, Total Reward: 66.1577250262995
# Episode 308, Total Reward: 234.18279278161492
# Episode 309, Total Reward: 84.70457988647374
# Episode 310, Total Reward: 184.35549166935354
# Episode 311, Total Reward: -135.32919191011158
# Episode 312, Total Reward: 79.14420917176047
# Episode 313, Total Reward: -13.558281422980528
# Episode 314, Total Reward: -114.46081165161867
# Episode 315, Total Reward: -90.84631842759806
# Episode 316, Total Reward: -41.232442103965184
# Episode 317, Total Reward: -80.55920657286059
# Episode 318, Total Reward: -132.08607348394625
# Episode 319, Total Reward: -129.1435809894894
# Episode 320, Total Reward: 126.42294525516064
# Episode 321, Total Reward: -169.2461829364978
# Episode 322, Total Reward: -178.58559153721225
# Episode 323, Total Reward: -17.88433580467816
# Episode 324, Total Reward: -229.96907415895518
# Episode 325, Total Reward: 101.43638305820264
# Episode 326, Total Reward: -106.98552428635898
# Episode 327, Total Reward: 98.17359749668138
# Episode 328, Total Reward: -85.48301308973305
# Episode 329, Total Reward: -33.70136449215448
# Episode 330, Total Reward: -116.34740419015375
# Episode 331, Total Reward: -111.16777399214703
# Episode 332, Total Reward: 33.35133497091945
# Episode 333, Total Reward: -88.76645512780264
# Episode 334, Total Reward: 23.86586376254816
# Episode 335, Total Reward: -12.785643193030808
# Episode 336, Total Reward: 38.08140929372175
# Episode 337, Total Reward: -179.77165632861798
# Episode 338, Total Reward: -199.6218624697674
# Episode 339, Total Reward: 46.205941811508424
# Episode 340, Total Reward: 221.91302209406246
# Episode 341, Total Reward: -46.34354511479785
# Episode 342, Total Reward: -67.24551979477076
# Episode 343, Total Reward: -86.20908871645707
# Episode 344, Total Reward: -70.30659563634866
# Episode 345, Total Reward: -34.928461196799944
# Episode 346, Total Reward: -127.75045698569471
# Episode 347, Total Reward: -75.31462896907712
# Episode 348, Total Reward: 102.72641924432193
# Episode 349, Total Reward: -95.79397121058588
# Episode 350, Total Reward: -67.94143679618762
# Checkpoint saved at episode 350
# Episode 351, Total Reward: -73.97205500271306
# Episode 352, Total Reward: 258.99661510903013
# Episode 353, Total Reward: -156.58103128146314
# Episode 354, Total Reward: -16.622268968193026
# Episode 355, Total Reward: -12.257190918696566
# Episode 356, Total Reward: -95.89134975288712
# Episode 357, Total Reward: 216.2307925692746
# Episode 358, Total Reward: -128.03371523260785
# Episode 359, Total Reward: 196.32944275889335
# Episode 360, Total Reward: -8.319302864664099
# Episode 361, Total Reward: -79.49656312213926
# Episode 362, Total Reward: -34.890810034572326
# Episode 363, Total Reward: 27.421825475312918
# Episode 364, Total Reward: -169.5318316573894
# Episode 365, Total Reward: -121.02159504431421
# Episode 366, Total Reward: -108.2713035386587
# Episode 367, Total Reward: -145.23080441102076
# Episode 368, Total Reward: -208.67019062798832
# Episode 369, Total Reward: -167.3047425502032
# Episode 370, Total Reward: 189.99817537625114
# Episode 371, Total Reward: 139.26826424040095
# Episode 372, Total Reward: -114.27404117647357
# Episode 373, Total Reward: -85.28513177545027
# Episode 374, Total Reward: -42.62534536229363
# Episode 375, Total Reward: 192.33013439119986
# Episode 376, Total Reward: 144.78644918620859
# Episode 377, Total Reward: -139.4957173222088
# Episode 378, Total Reward: -150.1166926580372
# Episode 379, Total Reward: -2.8696484883927837
# Episode 380, Total Reward: 211.50981253311437
# Episode 381, Total Reward: -204.20952717029456
# Episode 382, Total Reward: 197.89513271143775
# Episode 383, Total Reward: 189.09912471558522
# Episode 384, Total Reward: 193.4140946790401
# Episode 385, Total Reward: 4.297168543446233
# Episode 386, Total Reward: -102.8424170106511
# Episode 387, Total Reward: -63.20366075541057
# Episode 388, Total Reward: -128.71264307987343
# Episode 389, Total Reward: 224.9330227704266
# Episode 390, Total Reward: -38.958834430639186
# Episode 391, Total Reward: -193.08959891825688
# Episode 392, Total Reward: 247.8950981442182
# Episode 393, Total Reward: -5.734349186258088
# Episode 394, Total Reward: -197.33056184658716
# Episode 395, Total Reward: -4.8164473739605
# Episode 396, Total Reward: -183.98240319234964
# Episode 397, Total Reward: -109.29193968384422
# Episode 398, Total Reward: -194.04312626276513
# Episode 399, Total Reward: -106.1866079232858
# Episode 400, Total Reward: 156.0830886109953
# Checkpoint saved at episode 400
# Episode 401, Total Reward: 239.28966847134205
# Episode 402, Total Reward: 14.302483926434235
# Episode 403, Total Reward: -254.72867937210032
# Episode 404, Total Reward: 251.89741092831943
# Episode 405, Total Reward: -149.38356706546224
# Episode 406, Total Reward: 259.56676705436433
# Episode 407, Total Reward: 36.21405475440642
# Episode 408, Total Reward: 26.88249122748914
# Episode 409, Total Reward: 248.60015458456294
# Episode 410, Total Reward: -126.8986759420373
# Episode 411, Total Reward: -112.07947048082988
# Episode 412, Total Reward: -16.29308891320524
# Episode 413, Total Reward: -14.852578445648092
# Episode 414, Total Reward: -57.949763875509944
# Episode 415, Total Reward: -111.86753171368242
# Episode 416, Total Reward: -185.55669933549834
# Episode 417, Total Reward: 215.30809979684955
# Episode 418, Total Reward: -41.818501982584976
# Episode 419, Total Reward: -193.65439689026528
# Episode 420, Total Reward: 190.87484977113485
# Episode 421, Total Reward: 196.21409089094374
# Episode 422, Total Reward: -69.9829808376228
# Episode 423, Total Reward: -88.56418880104695
# Episode 424, Total Reward: -187.73344113302832
# Episode 425, Total Reward: -195.7600312424629
# Episode 426, Total Reward: -44.4427446406156
# Episode 427, Total Reward: 220.18184189712903
# Episode 428, Total Reward: -69.75561766168606
# Episode 429, Total Reward: -62.69547865741309
# Episode 430, Total Reward: -98.25957486410498
# Episode 431, Total Reward: -41.66347446850772
# Episode 432, Total Reward: -45.124190928497455
# Episode 433, Total Reward: 224.5729061914064
# Episode 434, Total Reward: -76.26091938831081
# Episode 435, Total Reward: -25.325843503650656
# Episode 436, Total Reward: 245.76512685788205
# Episode 437, Total Reward: -23.93317010695024
# Episode 438, Total Reward: -49.968215891566814
# Episode 439, Total Reward: -60.46073080031212
# Episode 440, Total Reward: -70.81190522808292
# Episode 441, Total Reward: -70.70590889527999
# Episode 442, Total Reward: -67.07947337314036
# Episode 443, Total Reward: -65.56503294000645
# Episode 444, Total Reward: -70.52347000129633
# Episode 445, Total Reward: -74.65767021632871
# Episode 446, Total Reward: 115.21808358312576
# Episode 447, Total Reward: -59.73318882636711
# Episode 448, Total Reward: -47.44723251528671
# Episode 449, Total Reward: -89.89760274101074
# Episode 450, Total Reward: -115.09521551795997
# Checkpoint saved at episode 450
# Episode 451, Total Reward: -49.80407752815363
# Episode 452, Total Reward: -83.06329333889579
# Episode 453, Total Reward: -97.91738669659316
# Episode 454, Total Reward: -81.13320680379319
# Episode 455, Total Reward: -151.61795349136952
# Episode 456, Total Reward: -107.4198648617921
# Episode 457, Total Reward: -55.05924502615228
# Episode 458, Total Reward: -100.31469084476653
# Episode 459, Total Reward: -191.6982464872598
# Episode 460, Total Reward: -111.8116365599952
# Episode 461, Total Reward: -89.25005199217166
# Episode 462, Total Reward: 121.59877767468713
# Episode 463, Total Reward: -98.93947188121217
# Episode 464, Total Reward: -109.08676048084034
# Episode 465, Total Reward: -90.49334533571538
# Episode 466, Total Reward: -100.96265671881608
# Episode 467, Total Reward: -105.16944265307386
# Episode 468, Total Reward: 85.4488996965558
# Episode 469, Total Reward: -103.55465112375826
# Episode 470, Total Reward: -126.45592855179656
# Episode 471, Total Reward: -167.0854783747057
# Episode 472, Total Reward: -152.7133687112431
# Episode 473, Total Reward: -91.80879289236732
# Episode 474, Total Reward: -74.11194739385596
# Episode 475, Total Reward: -169.5079226490272
# Episode 476, Total Reward: 35.381758510938255
# Episode 477, Total Reward: 40.74280042895873
# Episode 478, Total Reward: -103.38562898127378
# Episode 479, Total Reward: -105.44166553598133
# Episode 480, Total Reward: -151.13001410359777
# Episode 481, Total Reward: -89.26788150913103
# Episode 482, Total Reward: -107.10195694977334
# Episode 483, Total Reward: 133.64721686254364
# Episode 484, Total Reward: 164.4809236742468
# Episode 485, Total Reward: 155.65716866093106
# Episode 486, Total Reward: -61.11230962070982
# Episode 487, Total Reward: -89.79653394345007
# Episode 488, Total Reward: 224.54035613230775
# Episode 489, Total Reward: -74.26564770478505
# Episode 490, Total Reward: -23.457619175313837
# Episode 491, Total Reward: -106.08337899103591
# Episode 492, Total Reward: -101.79876942189277
# Episode 493, Total Reward: -34.90788798988626
# Episode 494, Total Reward: -84.36314568930064
# Episode 495, Total Reward: 147.57905615207147
# Episode 496, Total Reward: -57.29686367852442
# Episode 497, Total Reward: -88.74415602990591
# Episode 498, Total Reward: -79.77119978863774
# Episode 499, Total Reward: -61.956770629854915
# Episode 500, Total Reward: 172.37286564150875
# Checkpoint saved at episode 500
# Episode 501, Total Reward: -144.10908389272248
# Episode 502, Total Reward: -104.75253783771284
# Episode 503, Total Reward: -140.9949833102175
# Episode 504, Total Reward: 190.55300700629772
# Episode 505, Total Reward: -111.44209429892308
# Episode 506, Total Reward: -63.75902845518147
# Episode 507, Total Reward: 22.31281175474511
# Episode 508, Total Reward: -89.14630501749738
# Episode 509, Total Reward: -86.89498075236965
# Episode 510, Total Reward: -78.28051000663376
# Episode 511, Total Reward: -82.18832249813774
# Episode 512, Total Reward: -24.25780564483138
# Episode 513, Total Reward: -100.69639290904185
# Episode 514, Total Reward: -95.75534233661497
# Episode 515, Total Reward: 73.9861809931734
# Episode 516, Total Reward: -101.28386570681528
# Episode 517, Total Reward: -62.321937540122555
# Episode 518, Total Reward: 193.42872201584981
# Episode 519, Total Reward: 176.57944322306068
# Episode 520, Total Reward: -61.15450740621257
# Episode 521, Total Reward: 171.65182766850273
# Episode 522, Total Reward: -76.67356817397281
# Episode 523, Total Reward: -91.0805949210577
# Episode 524, Total Reward: 51.96979672347892
# Episode 525, Total Reward: 121.29425033218308
# Episode 526, Total Reward: -93.44436427728353
# Episode 527, Total Reward: 198.43079332767098
# Episode 528, Total Reward: -47.21450572189532
# Episode 529, Total Reward: 169.41772989106315
# Episode 530, Total Reward: 187.90409456362426
# Episode 531, Total Reward: -68.23051052880095
# Episode 532, Total Reward: -33.73256107191969
# Episode 533, Total Reward: -101.26429544258983
# Episode 534, Total Reward: -47.32400561042151
# Episode 535, Total Reward: 156.54519671307594
# Episode 536, Total Reward: -29.44254232293423
# Episode 537, Total Reward: 178.47717855692366
# Episode 538, Total Reward: 129.11171247576698
# Episode 539, Total Reward: -13.378357937940123
# Episode 540, Total Reward: -66.1439609019753
# Episode 541, Total Reward: 163.71230039484573
# Episode 542, Total Reward: 124.03965095508704
# Episode 543, Total Reward: 145.90097463659308
# Episode 544, Total Reward: 146.07293779669345
# Episode 545, Total Reward: -44.536489092351246
# Episode 546, Total Reward: -50.59772868290169
# Episode 547, Total Reward: 96.48002700418867
# Episode 548, Total Reward: -69.72148436619828
# Episode 549, Total Reward: -52.51480868984915
# Episode 550, Total Reward: -77.10422619536848
# Checkpoint saved at episode 550
# Episode 551, Total Reward: -65.90496749498277
# Episode 552, Total Reward: 158.0885791733828
# Episode 553, Total Reward: 171.36320932386158
# Episode 554, Total Reward: -68.39117538774028
# Episode 555, Total Reward: -91.72078498847124
# Episode 556, Total Reward: -149.24383950659177
# Episode 557, Total Reward: 163.65170453767186
# Episode 558, Total Reward: 154.77261279644125
# Episode 559, Total Reward: 64.53650349012713
# Episode 560, Total Reward: -41.57269097038784
# Episode 561, Total Reward: -51.3806033438742
# Episode 562, Total Reward: 139.1450476079721
# Episode 563, Total Reward: -80.22630972362865
# Episode 564, Total Reward: 160.6144166363988
# Episode 565, Total Reward: -84.40961026469222
# Episode 566, Total Reward: -26.13945786728678
# Episode 567, Total Reward: -60.411930206207884
# Episode 568, Total Reward: -35.19183719072055
# Episode 569, Total Reward: -38.449143555880326
# Episode 570, Total Reward: -14.190121392416117
# Episode 571, Total Reward: -37.6706553463692
# Episode 572, Total Reward: -60.55860026167301
# Episode 573, Total Reward: -50.90326987200166
# Episode 574, Total Reward: -43.27215736916945
# Episode 575, Total Reward: 81.60461126811576
# Episode 576, Total Reward: -79.44714335107366
# Episode 577, Total Reward: -64.10211942690447
# Episode 578, Total Reward: -94.71312998310907
# Episode 579, Total Reward: 72.08689706244715
# Episode 580, Total Reward: -67.84330175212153
# Episode 581, Total Reward: 189.99561636546738
# Episode 582, Total Reward: 192.3635235552445
# Episode 583, Total Reward: -60.06920936015877
# Episode 584, Total Reward: -37.22265895247689
# Episode 585, Total Reward: 157.96151005834543
# Episode 586, Total Reward: 6.367073959926373
# Episode 587, Total Reward: -60.27257083508089
# Episode 588, Total Reward: -14.530907626941172
# Episode 589, Total Reward: 179.05707740130612
# Episode 590, Total Reward: -79.67764264130346
# Episode 591, Total Reward: 77.95772783991488
# Episode 592, Total Reward: -35.472527282519195
# Episode 593, Total Reward: -63.986003166516895
# Episode 594, Total Reward: -75.68961771194111
# Episode 595, Total Reward: -95.99911264113216
# Episode 596, Total Reward: -38.834295561470014
# Episode 597, Total Reward: -81.7326957932336
# Episode 598, Total Reward: -5.9522929334248005
# Episode 599, Total Reward: -49.181590326718016
# Episode 600, Total Reward: 154.8926366600019
# Checkpoint saved at episode 600
# Episode 601, Total Reward: 64.642487485279
# Episode 602, Total Reward: -72.1923125367469
# Episode 603, Total Reward: 200.85119510310562
# Episode 604, Total Reward: 228.3911897508078
# Episode 605, Total Reward: 159.17064433303275
# Episode 606, Total Reward: -24.067761737446006
# Episode 607, Total Reward: 188.75575467979456
# Episode 608, Total Reward: 57.95345404955256
# Episode 609, Total Reward: -51.79075406928232
# Episode 610, Total Reward: -50.76173066541003
# Episode 611, Total Reward: 247.88642751783235
# Episode 612, Total Reward: -58.77081645414749
# Episode 613, Total Reward: -24.876945445338507
# Episode 614, Total Reward: -83.00263217827808
# Episode 615, Total Reward: 198.7485200329391
# Episode 616, Total Reward: -92.28617144823986
# Episode 617, Total Reward: 178.9089968659863
# Episode 618, Total Reward: -106.3218174049586
# Episode 619, Total Reward: -86.25935181330976
# Episode 620, Total Reward: -29.143743933177674
# Episode 621, Total Reward: -22.085714880058234
# Episode 622, Total Reward: -45.98241601033655
# Episode 623, Total Reward: -47.91503922661682
# Episode 624, Total Reward: -104.37545539875826
# Episode 625, Total Reward: -75.1139264117233
# Episode 626, Total Reward: 175.97869409295907
# Episode 627, Total Reward: -19.678875154129017
# Episode 628, Total Reward: -115.36963608303935
# Episode 629, Total Reward: -123.2353425243821
# Episode 630, Total Reward: -36.28341732167898
# Episode 631, Total Reward: -41.38030884880354
# Episode 632, Total Reward: -81.65027528489921
# Episode 633, Total Reward: -50.58868370664108
# Episode 634, Total Reward: -51.68149085771667
# Episode 635, Total Reward: -29.601584320261097
# Episode 636, Total Reward: -73.54836243054044
# Episode 637, Total Reward: -118.77063294330519
# Episode 638, Total Reward: -118.09111035753841
# Episode 639, Total Reward: -46.24543829592112
# Episode 640, Total Reward: -62.87194700997776
# Episode 641, Total Reward: -62.35839917217291
# Episode 642, Total Reward: -66.34769178832434
# Episode 643, Total Reward: -101.10669189246087
# Episode 644, Total Reward: -29.66783289013442
# Episode 645, Total Reward: -142.2400788661579
# Episode 646, Total Reward: -111.44084256811048
# Episode 647, Total Reward: -126.25815506139925
# Episode 648, Total Reward: -66.9831542760619
# Episode 649, Total Reward: -107.64550005863055
# Episode 650, Total Reward: -130.24044345808105
# Checkpoint saved at episode 650
# Episode 651, Total Reward: -45.94169926803828
# Episode 652, Total Reward: -109.02159745063973
# Episode 653, Total Reward: -116.72226808305044
# Episode 654, Total Reward: -120.06266085345241
# Episode 655, Total Reward: -116.34874247827301
# Episode 656, Total Reward: -98.37075965635533
# Episode 657, Total Reward: -61.258156756511454
# Episode 658, Total Reward: -45.13358948521791
# Episode 659, Total Reward: -118.28231070660897
# Episode 660, Total Reward: -104.47020020818323
# Episode 661, Total Reward: -139.7433610545519
# Episode 662, Total Reward: -114.29743044842873
# Episode 663, Total Reward: -83.99230462987515
# Episode 664, Total Reward: -89.62817742891389
# Episode 665, Total Reward: -138.89147567672794
# Episode 666, Total Reward: -109.68773299471181
# Episode 667, Total Reward: -32.8322038155636
# Episode 668, Total Reward: -106.70996273626433
# Episode 669, Total Reward: -120.05222644779928
# Episode 670, Total Reward: -165.0158409170498
# Episode 671, Total Reward: -137.57331402896745
# Episode 672, Total Reward: -106.69717066122904
# Episode 673, Total Reward: -91.03070389427499
# Episode 674, Total Reward: -92.43289496387428
# Episode 675, Total Reward: -113.79833241283384
# Episode 676, Total Reward: -114.20651648009773
# Episode 677, Total Reward: -93.77905831690768
# Episode 678, Total Reward: 38.375880084296426
# Episode 679, Total Reward: -40.51582832043324
# Episode 680, Total Reward: -79.91146719600843
# Episode 681, Total Reward: -57.235932789328324
# Episode 682, Total Reward: -89.62816818452893
# Episode 683, Total Reward: 230.97504580236395
# Episode 684, Total Reward: -131.0060610052047
# Episode 685, Total Reward: -119.00021475771737
# Episode 686, Total Reward: 12.256754350625329
# Episode 687, Total Reward: -80.70177953435473
# Episode 688, Total Reward: 217.56257111292967
# Episode 689, Total Reward: -120.87984086448688
# Episode 690, Total Reward: -103.85592270673241
# Episode 691, Total Reward: -71.02283442286743
# Episode 692, Total Reward: -27.55982763534729
# Episode 693, Total Reward: 237.00020578062458
# Episode 694, Total Reward: -69.37550100878966
# Episode 695, Total Reward: -28.69870866923648
# Episode 696, Total Reward: -42.530910102730246
# Episode 697, Total Reward: 254.73046849060913
# Episode 698, Total Reward: -59.27194623234905
# Episode 699, Total Reward: -82.02560159677721
# Episode 700, Total Reward: -90.92680578767396
# Checkpoint saved at episode 700
# Episode 701, Total Reward: -11.962692372592187
# Episode 702, Total Reward: -87.16669105858242
# Episode 703, Total Reward: 249.30008093583905
# Episode 704, Total Reward: -89.02859598294455
# Episode 705, Total Reward: -57.85655972278457
# Episode 706, Total Reward: 11.733056862205785
# Episode 707, Total Reward: -106.49104316122997
# Episode 708, Total Reward: -95.9125618169621
# Episode 709, Total Reward: -57.45740564089041
# Episode 710, Total Reward: -106.15346469703277
# Episode 711, Total Reward: -80.81843124365956
# Episode 712, Total Reward: -18.415795453663335
# Episode 713, Total Reward: -68.44739308628566
# Episode 714, Total Reward: -53.12553196457786
# Episode 715, Total Reward: -56.0523134163852
# Episode 716, Total Reward: -61.43649709438237
# Episode 717, Total Reward: -103.24241162681766
# Episode 718, Total Reward: 16.31423373093233
# Episode 719, Total Reward: 249.46450335171545
# Episode 720, Total Reward: -93.38343343260978
# Episode 721, Total Reward: -117.49856129992365
# Episode 722, Total Reward: -58.1979526275217
# Episode 723, Total Reward: -11.260558235842296
# Episode 724, Total Reward: 214.4000601811863
# Episode 725, Total Reward: -107.77194266322661
# Episode 726, Total Reward: -44.97661927596981
# Episode 727, Total Reward: -107.77675189113931
# Episode 728, Total Reward: 258.19011551750805
# Episode 729, Total Reward: -99.31213663981177
# Episode 730, Total Reward: -64.96095247836999
# Episode 731, Total Reward: -86.97681832893178
# Episode 732, Total Reward: -0.8992308367390223
# Episode 733, Total Reward: -111.53838887244065
# Episode 734, Total Reward: 5.304879153460547
# Episode 735, Total Reward: -64.66685727006211
# Episode 736, Total Reward: -20.59330442018772
# Episode 737, Total Reward: -116.8111916014873
# Episode 738, Total Reward: 4.119534781809364
# Episode 739, Total Reward: -65.31444990049194
# Episode 740, Total Reward: -19.30842273003229
# Episode 741, Total Reward: 252.08435725370796
# Episode 742, Total Reward: 227.46612013336494
# Episode 743, Total Reward: 202.6407596901659
# Episode 744, Total Reward: -91.71128992183533
# Episode 745, Total Reward: -46.499260171999424
# Episode 746, Total Reward: -48.55957598202407
# Episode 747, Total Reward: -59.45391271228182
# Episode 748, Total Reward: 224.1345315642573
# Episode 749, Total Reward: -38.53793163842428
# Episode 750, Total Reward: -24.816033133964282
# Checkpoint saved at episode 750
# Episode 751, Total Reward: -13.993555173265662
# Episode 752, Total Reward: -77.75584534652185
# Episode 753, Total Reward: 4.1535475906951405
# Episode 754, Total Reward: -6.342258514633315
# Episode 755, Total Reward: -94.78565858967066
# Episode 756, Total Reward: 235.30939805296143
# Episode 757, Total Reward: -123.00019614250236
# Episode 758, Total Reward: -117.04207489252025
# Episode 759, Total Reward: -91.16590899365556
# Episode 760, Total Reward: -77.82028952227714
# Episode 761, Total Reward: -92.4455742327147
# Episode 762, Total Reward: -35.32453447182482
# Episode 763, Total Reward: -120.73723021917289
# Episode 765, Total Reward: -108.97935759204663
# Episode 766, Total Reward: -9.680087207780858
# Episode 767, Total Reward: -122.64312823860013
# Episode 768, Total Reward: -101.78619459994
# Episode 769, Total Reward: -96.22524590237055
# Episode 770, Total Reward: -104.43506514431208
# Episode 771, Total Reward: -115.38969807266926
# Episode 772, Total Reward: -129.52956886907438
# Episode 773, Total Reward: -117.50575037989906
# Episode 774, Total Reward: -128.33408470864617
# Episode 775, Total Reward: -131.8073092986886
# Episode 776, Total Reward: -118.84141151403178
# Episode 777, Total Reward: -123.92120678042544
# Episode 778, Total Reward: -109.58733707991958
# Episode 779, Total Reward: -125.72720392351513
# Episode 780, Total Reward: -117.49416863262294
# Episode 781, Total Reward: -78.32908825459991
# Episode 782, Total Reward: -106.55496977520157
# Episode 783, Total Reward: -129.33720108382406
# Episode 784, Total Reward: -114.06746682537405
# Episode 785, Total Reward: -117.60097124945253
# Episode 786, Total Reward: -108.40250219221288
# Episode 787, Total Reward: -102.99639549653045
# Episode 788, Total Reward: -119.89625863848912
# Episode 789, Total Reward: -124.11369828881038
# Episode 790, Total Reward: -124.05853442544702
# Episode 791, Total Reward: -107.39895216484129
# Episode 792, Total Reward: -92.68793885055416
# Episode 793, Total Reward: -109.34432526136553
# Episode 794, Total Reward: -111.6445011730954
# Episode 795, Total Reward: -123.34998889066944
# Episode 796, Total Reward: -108.79062864544889
# Episode 797, Total Reward: -97.66834528997377
# Episode 798, Total Reward: -127.02535487054773
# Episode 799, Total Reward: -108.17014414986322
# Episode 800, Total Reward: -106.62936687096617
# Checkpoint saved at episode 800
# Episode 801, Total Reward: -117.45810665291732
# Episode 802, Total Reward: -107.21366253273507
# Episode 803, Total Reward: -128.75640549321548
# Episode 804, Total Reward: -129.52712836466256
# Episode 805, Total Reward: -110.14088101872302
# Episode 806, Total Reward: -100.322887035322
# Episode 807, Total Reward: -119.48703793637345
# Episode 808, Total Reward: -110.34564608384147
# Episode 809, Total Reward: -126.35907261772255
# Episode 810, Total Reward: -114.24258765923186
# Episode 811, Total Reward: -111.68834748701238
# Episode 812, Total Reward: -103.76880246301309
# Episode 813, Total Reward: -85.71289446634015
# Episode 814, Total Reward: -121.08175153657294
# Episode 815, Total Reward: -115.96493304231379
# Episode 816, Total Reward: -115.36593855767978
# Episode 817, Total Reward: -90.91948062253587
# Episode 818, Total Reward: -113.665622422389
# Episode 819, Total Reward: -110.49772902161146
# Episode 820, Total Reward: -100.85544327754846
# Episode 821, Total Reward: -130.86486438233453
# Episode 822, Total Reward: -86.63630665612695
# Episode 823, Total Reward: -113.60660991787955
# Episode 824, Total Reward: -105.44509718988824
# Episode 825, Total Reward: -100.57989777952403
# Episode 826, Total Reward: -114.8242137890688
# Episode 827, Total Reward: -108.3003720550902
# Episode 828, Total Reward: -80.76473812051393
# Episode 829, Total Reward: -115.67577096450259
# Episode 830, Total Reward: -114.4621981681367
# Episode 831, Total Reward: -108.69136893404618
# Episode 832, Total Reward: -118.52076582437789
# Episode 833, Total Reward: -88.85316115332529
# Episode 834, Total Reward: -122.49716906877865
# Episode 835, Total Reward: -92.64088546072504
# Episode 836, Total Reward: -113.60639199215393
# Episode 837, Total Reward: -113.43510498731573
# Episode 838, Total Reward: -98.78632214021198
# Episode 839, Total Reward: -102.64827676528591
# Episode 840, Total Reward: -93.73529193394876
# Episode 841, Total Reward: -111.63724266785476
# Episode 842, Total Reward: -109.87645051862975
# Episode 843, Total Reward: -91.3273274823411
# Episode 844, Total Reward: -109.93759194149163
# Episode 845, Total Reward: -104.12332201751971
# Episode 846, Total Reward: -86.73054660162109
# Episode 847, Total Reward: -114.15369856737514
# Episode 848, Total Reward: -106.19768679652316
# Episode 849, Total Reward: -80.25148380088336
# Episode 850, Total Reward: -79.89969380787444
# Checkpoint saved at episode 850
# Episode 851, Total Reward: -122.8631986431638
# Episode 852, Total Reward: -90.3880420880675
# Episode 853, Total Reward: -127.66769467355587
# Episode 854, Total Reward: -125.94331270655186
# Episode 855, Total Reward: -94.52855800255477
# Episode 856, Total Reward: -121.35009463115635
# Episode 857, Total Reward: -106.83331507560217
# Episode 858, Total Reward: -106.81451088085353
# Episode 859, Total Reward: -115.08049953598601
# Episode 860, Total Reward: -114.88248718213549
# Episode 861, Total Reward: -127.30281253364527
# Episode 862, Total Reward: -102.81744258040652
# Episode 863, Total Reward: -104.41849163527263
# Episode 864, Total Reward: -111.63842785000918
# Episode 865, Total Reward: -112.46686846759505
# Episode 866, Total Reward: -107.820493329404
# Episode 867, Total Reward: -98.34749679535535
# Episode 868, Total Reward: -104.23329157168894
# Episode 869, Total Reward: -128.66495105122283
# Episode 870, Total Reward: -92.22615005933226
# Episode 871, Total Reward: -101.77057120354797
# Episode 872, Total Reward: -110.22420492429845
# Episode 873, Total Reward: -117.85072786851623
# Episode 874, Total Reward: -119.31354385579802
# Episode 875, Total Reward: -124.50282564903307
# Episode 876, Total Reward: -104.99052750840498
# Episode 877, Total Reward: -121.10807857376159
# Episode 878, Total Reward: -93.62722186666626
# Episode 879, Total Reward: -112.05093652458385
# Episode 880, Total Reward: -111.6640226397635
# Episode 881, Total Reward: -125.09023040485036
# Episode 882, Total Reward: -111.57895960476637
# Episode 883, Total Reward: -97.61536609224967
# Episode 884, Total Reward: -118.83302734924624
# Episode 885, Total Reward: -119.59831099639194
# Episode 886, Total Reward: -112.11209173848414
# Episode 887, Total Reward: -102.15632533321812
# Episode 888, Total Reward: -82.37730734057968
# Episode 889, Total Reward: -99.13159148475074
# Episode 890, Total Reward: -118.1412599221055
# Episode 891, Total Reward: -102.0202296038357
# Episode 892, Total Reward: -102.83547904017355
# Episode 893, Total Reward: -118.97233181805548
# Episode 894, Total Reward: -112.30185633761376
# Episode 895, Total Reward: -103.82895839697936
# Episode 896, Total Reward: -106.70921820700929
# Episode 897, Total Reward: -106.63053072428792
# Episode 898, Total Reward: -110.37933629785411
# Episode 899, Total Reward: -118.67488795742844
# Episode 900, Total Reward: -123.45019956290943
# Checkpoint saved at episode 900
# Episode 901, Total Reward: -129.1950927176653
# Episode 902, Total Reward: -118.71174562108223
# Episode 903, Total Reward: -98.78459394862236
# Episode 904, Total Reward: -101.98906507734388
# Episode 905, Total Reward: -114.16478127812849
# Episode 906, Total Reward: -116.21821330816248
# Episode 907, Total Reward: -83.61154543817932
# Episode 908, Total Reward: -97.32377086664296
# Episode 909, Total Reward: -102.11046344730585
# Episode 910, Total Reward: -110.43455191072226
# Episode 911, Total Reward: -110.17519836950993
# Episode 912, Total Reward: -107.8420590746572
# Episode 913, Total Reward: -116.36425706108895
# Episode 914, Total Reward: -133.3780648866424
# Episode 915, Total Reward: -100.89062221194169
# Episode 916, Total Reward: -108.28670254480372
# Episode 917, Total Reward: -115.8821531874783
# Episode 918, Total Reward: -104.24111307140721
# Episode 919, Total Reward: -119.68892021457333
# Episode 920, Total Reward: -80.65607015353834
# Episode 921, Total Reward: -118.43791854782305
# Episode 922, Total Reward: -96.99694693915554
# Episode 923, Total Reward: -98.6866448028141
# Episode 924, Total Reward: -99.01131037205764
# Episode 925, Total Reward: -96.51242173105027
# Episode 926, Total Reward: -109.30291977975052
# Episode 927, Total Reward: -130.78151028925663
# Episode 928, Total Reward: -142.4794543710714
# Episode 929, Total Reward: -118.05649851520039
# Episode 930, Total Reward: -103.91199731620029
# Episode 931, Total Reward: -118.37916241119741
# Episode 932, Total Reward: -112.11643195695088
# Episode 933, Total Reward: -119.51103246337355
# Episode 934, Total Reward: -114.18169306943494
# Episode 935, Total Reward: -99.75792950976133
# Episode 936, Total Reward: -120.66703962958141
# Episode 937, Total Reward: -108.7037585936451
# Episode 938, Total Reward: -141.97642726553408
# Episode 939, Total Reward: -116.6800477480258
# Episode 940, Total Reward: -108.92669330285855
# Episode 941, Total Reward: -106.97404287469483
# Episode 942, Total Reward: -82.67195635859
# Episode 943, Total Reward: -109.73021532162134
# Episode 944, Total Reward: -92.91359977406435
# Episode 945, Total Reward: -84.75100542438973
# Episode 946, Total Reward: -114.54768858830835
# Episode 947, Total Reward: -116.0886985510889
# Episode 948, Total Reward: -113.964005935893
# Episode 949, Total Reward: -109.50806080450133
# Episode 950, Total Reward: -88.9926914463837
# Checkpoint saved at episode 950
# Episode 951, Total Reward: -101.22615378970357
# Episode 952, Total Reward: -100.19722633413753
# Episode 953, Total Reward: -106.39539719500408
# Episode 954, Total Reward: -111.92165460477331
# Episode 955, Total Reward: -66.47812910574109
# Episode 956, Total Reward: -119.42184130779401
# Episode 957, Total Reward: -101.9754273500641
# Episode 958, Total Reward: -100.06495453965297
# Episode 959, Total Reward: -117.55905826726912
# Episode 960, Total Reward: -32.047383833372095
# Episode 961, Total Reward: -132.81420376125624
# Episode 962, Total Reward: -119.4867678929762
# Episode 963, Total Reward: -117.20351911263705
# Episode 964, Total Reward: -105.07424143952308
# Episode 965, Total Reward: -88.0772137634738
# Episode 966, Total Reward: -93.70547104850479
# Episode 967, Total Reward: -91.24416332531736
# Episode 968, Total Reward: -92.83251407069807
# Episode 969, Total Reward: -95.90992779480452
# Episode 970, Total Reward: -122.85679068132413
# Episode 971, Total Reward: -112.97824998286586
# Episode 972, Total Reward: -96.68577047292911
# Episode 973, Total Reward: -117.57262040348527
# Episode 974, Total Reward: -104.00626050301322
# Episode 975, Total Reward: -95.32214137759135
# Episode 976, Total Reward: -123.3894232673136
# Episode 977, Total Reward: -89.74021495561215
# Episode 978, Total Reward: -117.99528675083778
# Episode 979, Total Reward: -110.87912442781797
# Episode 980, Total Reward: -133.29880446758682
# Episode 981, Total Reward: -112.5637519324379
# Episode 982, Total Reward: -115.2507854598723
# Episode 983, Total Reward: -117.29961891034729
# Episode 984, Total Reward: -91.64320359135493
# Episode 985, Total Reward: -116.30745214862208
# Episode 986, Total Reward: -91.12616729020313
# Episode 987, Total Reward: -129.15149236468017
# Episode 988, Total Reward: -92.24839592253036
# Episode 989, Total Reward: -94.56846255841613
# Episode 990, Total Reward: -97.04843370646215
# Episode 991, Total Reward: -116.36158746641053
# Episode 992, Total Reward: -132.48932025859187
# Episode 993, Total Reward: -86.07467708602472
# Episode 994, Total Reward: -108.14917098223866
# Episode 995, Total Reward: -101.0099340924215
# Episode 996, Total Reward: -126.02411307873177
# Episode 997, Total Reward: -96.90841888884006
# Episode 998, Total Reward: -121.30380658857958
# Episode 999, Total Reward: -114.74286153407928
# Episode 1000, Total Reward: -120.87194929186654
# Checkpoint saved at episode 1000
# Episode 1001, Total Reward: -72.48630990781282
# Episode 1002, Total Reward: -83.55953128016027
# Episode 1003, Total Reward: -109.01569108052465
# Episode 1004, Total Reward: -95.98397994828868
# Episode 1005, Total Reward: -115.74737924415484
# Episode 1006, Total Reward: -108.68711598493321
# Episode 1007, Total Reward: -90.53150349583576
# Episode 1008, Total Reward: -127.60729821668878
# Episode 1009, Total Reward: -119.70883579711511
# Episode 1010, Total Reward: -73.06503453836079
# Episode 1011, Total Reward: -117.31506446995587
# ...
# Episode 1446, Total Reward: -135.49204292261402
# Episode 1447, Total Reward: -106.71885227074954
# Episode 1448, Total Reward: -118.26293932013853
# Episode 1449, Total Reward: -110.46222358767416
# Episode 1450, Total Reward: -109.48308263763177
# Checkpoint saved at episode 1450
# Episode 1451, Total Reward: -127.4531036636653
# Episode 1452, Total Reward: -150.91464259562636
# Episode 1453, Total Reward: -107.38671604607542
# Episode 1454, Total Reward: -125.19715106710424
# Episode 1455, Total Reward: -142.8110267314545
# Episode 1456, Total Reward: -146.3116060853576
# Episode 1457, Total Reward: -121.62286741457245
# Episode 1458, Total Reward: -111.8431666334248
# Episode 1459, Total Reward: -141.76706814870673
# Episode 1460, Total Reward: -99.09456967472568
# Episode 1461, Total Reward: -115.07912387182536
# Episode 1462, Total Reward: -180.37047626656698
# Episode 1463, Total Reward: -108.40698579613519
# Episode 1464, Total Reward: -151.22930998397038
# Episode 1465, Total Reward: -96.09404747254385
# Episode 1466, Total Reward: -129.28175159740047
# Episode 1467, Total Reward: -135.03260496757485
# Episode 1468, Total Reward: -142.1240234394905
# Episode 1469, Total Reward: -113.20506864106405
# Episode 1470, Total Reward: -107.28257083843364
# Episode 1471, Total Reward: -108.64343038759807
# Episode 1472, Total Reward: -111.91177531595552
# Episode 1473, Total Reward: -94.99479708380902
# Episode 1474, Total Reward: -130.313940090293
# Episode 1475, Total Reward: -113.37203004539653
# Episode 1476, Total Reward: -129.72947396074622
# Episode 1477, Total Reward: -137.8615080271506
# Episode 1478, Total Reward: -118.5429928086042
# Episode 1479, Total Reward: -121.76922857316843
# Episode 1480, Total Reward: -129.55677241057123
# Episode 1481, Total Reward: -135.5343494396846
# Episode 1482, Total Reward: -127.51148250736371
# Episode 1483, Total Reward: -111.17199287523346
# Episode 1484, Total Reward: -107.58851650434562
# Episode 1485, Total Reward: -143.86628476876342
# Episode 1486, Total Reward: -133.159517891357
# Episode 1487, Total Reward: -118.50229342192567
# Episode 1488, Total Reward: -150.54887195839012
# Episode 1489, Total Reward: -161.2350811791557
# Episode 1490, Total Reward: -126.4963404549787
# Episode 1491, Total Reward: -123.0152234480833
# Episode 1492, Total Reward: -202.56648866871967
# Episode 1493, Total Reward: -140.22114581029572
# Episode 1494, Total Reward: -112.11981436562344
# Episode 1495, Total Reward: -123.87261682375527
# Episode 1496, Total Reward: -157.6251744267188
# Episode 1497, Total Reward: -176.81402950023454
# Episode 1498, Total Reward: -126.96404531597052
# Episode 1499, Total Reward: -114.32261362458551
# Episode 1500, Total Reward: -119.06030859925525
# Checkpoint saved at episode 1500
# Episode 1501, Total Reward: -133.5133439439733
# Episode 1502, Total Reward: -101.95645916730332
# Episode 1503, Total Reward: -125.58874375442551
# Episode 1504, Total Reward: -154.26000756304032
# Episode 1505, Total Reward: -154.14104343641537
# Episode 1506, Total Reward: -109.89099107861914
# Episode 1507, Total Reward: -106.08825586860462
# Episode 1508, Total Reward: -115.15984404927096
# Episode 1509, Total Reward: -129.95170984131101
# Episode 1510, Total Reward: -113.9365155108687
# Episode 1511, Total Reward: -136.28498741361938
# Episode 1512, Total Reward: -114.39826435398811
# Episode 1513, Total Reward: -110.30726123052149
# Episode 1514, Total Reward: -108.21314166375896
# Episode 1515, Total Reward: -130.5073412692298
# Episode 1516, Total Reward: -94.69536040154989
# Episode 1517, Total Reward: -102.88478340982087
# Episode 1518, Total Reward: -106.93556020155259
# Episode 1519, Total Reward: -65.04461097884959
# Episode 1520, Total Reward: -132.05965763347132
# Episode 1521, Total Reward: -124.09759409104674
# Episode 1522, Total Reward: -125.7855985852209
# Episode 1523, Total Reward: -65.41776570440533
# Episode 1524, Total Reward: -105.40749145312802
# Episode 1525, Total Reward: -116.13547754098
# Episode 1526, Total Reward: -134.1884377951497
# Episode 1527, Total Reward: -104.91656597370887
# Episode 1528, Total Reward: -125.18495477178006
# Episode 1529, Total Reward: -110.64250687905064
# Episode 1530, Total Reward: -129.72506062422028
# Episode 1531, Total Reward: -132.1760596051856
# Episode 1532, Total Reward: -121.5900658767093
# Episode 1533, Total Reward: -108.4298626494233
# Episode 1534, Total Reward: -58.068824563002636
# Episode 1535, Total Reward: -107.04196036873358
# Episode 1536, Total Reward: -67.99251440689669
# Episode 1537, Total Reward: -123.0740112919041
# Episode 1538, Total Reward: -126.45742920132315
# Episode 1539, Total Reward: -119.84243416730719
# Episode 1540, Total Reward: -110.0260901708557
# Episode 1541, Total Reward: -110.66473179100237
# Episode 1542, Total Reward: -103.70305671413044
# Episode 1543, Total Reward: -78.7061157518533
# Episode 1544, Total Reward: -95.04369555246387
# Episode 1545, Total Reward: -131.59671022273182
# Episode 1546, Total Reward: -130.3343491822822
# Episode 1547, Total Reward: -107.89735004080175
# Episode 1548, Total Reward: -112.92906255384526
# Episode 1549, Total Reward: -134.50300223671823
# Episode 1550, Total Reward: -116.74505175808625
# Checkpoint saved at episode 1550
# Episode 1551, Total Reward: -99.4618642971919
# Episode 1552, Total Reward: -127.48370823751037
# Episode 1553, Total Reward: -115.40073776517575
# Episode 1554, Total Reward: -108.79364608118053
# Episode 1555, Total Reward: -93.37090122435607
# Episode 1556, Total Reward: -101.34237855597996
# Episode 1557, Total Reward: -118.70295722667709
# Episode 1558, Total Reward: -119.0953921592834
# Episode 1559, Total Reward: -121.45761351591219
# Episode 1560, Total Reward: -112.42792043294965
# Episode 1561, Total Reward: -111.80272050695504
# Episode 1562, Total Reward: -71.21334913999
# Episode 1563, Total Reward: -129.26988462249682
# Episode 1564, Total Reward: -133.75533157800396
# Episode 1565, Total Reward: -47.90408957363252
# Episode 1566, Total Reward: -109.55445451855695
# Episode 1567, Total Reward: -107.80680379989668
# Episode 1568, Total Reward: -90.09280786699826
# Episode 1569, Total Reward: -110.64794552115428
# Episode 1570, Total Reward: -132.8415075422579
# Episode 1571, Total Reward: -115.23737054676673
# Episode 1572, Total Reward: -107.84954455629781
# Episode 1573, Total Reward: -109.6443393982052
# Episode 1574, Total Reward: -116.87925212186272
# Episode 1575, Total Reward: -122.18948783366994
# Episode 1576, Total Reward: -105.80066148812733
# Episode 1577, Total Reward: -114.63208267536321
# Episode 1578, Total Reward: -139.14200933330363
# Episode 1579, Total Reward: -107.92941278113723
# Episode 1580, Total Reward: -105.0564814235952
# Episode 1581, Total Reward: -129.63197856213617
# Episode 1582, Total Reward: -130.59365839493097
# Episode 1583, Total Reward: -118.4430080091164
# Episode 1584, Total Reward: -129.3572785389354
# Episode 1585, Total Reward: -126.07462729484945
# Episode 1586, Total Reward: -99.44677103738795
# Episode 1587, Total Reward: -110.26527093954921
# Episode 1588, Total Reward: -122.81785453241928
# Episode 1589, Total Reward: -118.80979588703383
# Episode 1590, Total Reward: -127.38453010205224
# Episode 1591, Total Reward: -116.42110969998836
# Episode 1592, Total Reward: -88.8825217203953
# Episode 1593, Total Reward: -132.06090179551722
# Episode 1594, Total Reward: -131.6582007934736
# Episode 1595, Total Reward: -148.66782217123347
# Episode 1596, Total Reward: -131.60289830307264
# Episode 1597, Total Reward: -102.04148072440113
# Episode 1598, Total Reward: -135.49902502652162
# Episode 1599, Total Reward: -129.99963589619838
# Episode 1600, Total Reward: -112.48292073387064
# Checkpoint saved at episode 1600
# Episode 1601, Total Reward: -97.97916680399256
# Episode 1602, Total Reward: -126.33638321961797
# Episode 1603, Total Reward: -123.7690691615532
# Episode 1604, Total Reward: -90.91124084893254
# Episode 1605, Total Reward: -116.95010634407296
# Episode 1606, Total Reward: -105.2994804268255
# Episode 1607, Total Reward: -83.87139737169022
# Episode 1608, Total Reward: -130.43816531398093
# Episode 1609, Total Reward: -129.1837770719612
# Episode 1610, Total Reward: -126.74316775503944
# Episode 1611, Total Reward: -122.50826189746104
# Episode 1612, Total Reward: -131.24357059305666
# Episode 1613, Total Reward: -117.16257351579544
# Episode 1614, Total Reward: -98.44139549605303
# Episode 1615, Total Reward: -123.84588039019131
# Episode 1616, Total Reward: -118.83145945674629
# Episode 1617, Total Reward: -117.08987009295447
# Episode 1618, Total Reward: -101.22197794526829
# Episode 1619, Total Reward: -116.06587331020768
# Episode 1620, Total Reward: -128.65815972889888
# Episode 1621, Total Reward: -99.95553375903306
# Episode 1622, Total Reward: -119.40806982805229
# Episode 1623, Total Reward: -135.6789634472682
# Episode 1624, Total Reward: -120.28063368308307
# Episode 1625, Total Reward: -117.64901351340079
# Episode 1626, Total Reward: -121.37893263933589
# Episode 1627, Total Reward: -119.74861339891663
# Episode 1628, Total Reward: -86.8928344999239
# Episode 1629, Total Reward: -88.69981563130605
# Episode 1630, Total Reward: -116.14922160280923
# Episode 1631, Total Reward: -105.16536640372063
# Episode 1632, Total Reward: -112.0694660089095
# Episode 1633, Total Reward: -110.06132732109023
# Episode 1634, Total Reward: -119.6156393636741
# Episode 1635, Total Reward: -122.98933352299134
# Episode 1636, Total Reward: -117.97059832236278
# Episode 1637, Total Reward: -123.5147488572197
# Episode 1638, Total Reward: -103.47403731988352
# Episode 1639, Total Reward: -100.94270262438694
# Episode 1640, Total Reward: -129.17591548620396
# Episode 1641, Total Reward: -101.6664331322488
# Episode 1642, Total Reward: -111.20471721070892
# Episode 1643, Total Reward: -119.95186757597344
# Episode 1644, Total Reward: -96.2284141696156
# Episode 1645, Total Reward: -126.64005676706942
# Episode 1646, Total Reward: -111.39628887390747
# Episode 1647, Total Reward: -131.59046525196794
# Episode 1648, Total Reward: -111.10547738716835
# Episode 1649, Total Reward: -141.33294832096126
# Episode 1650, Total Reward: -102.88853905780738
# Checkpoint saved at episode 1650
# Episode 1651, Total Reward: -93.5357358879933
# Episode 1652, Total Reward: -102.59506912438945
# Episode 1653, Total Reward: -103.97557354352097
# Episode 1654, Total Reward: -99.14393207586929
# Episode 1655, Total Reward: -105.7500621731302
# Episode 1656, Total Reward: -86.38394330652856
# Episode 1657, Total Reward: -104.8282298551671
# Episode 1658, Total Reward: -131.25997408283598
# Episode 1659, Total Reward: -96.28740712479511
# Episode 1660, Total Reward: -139.35107692520634
# Episode 1661, Total Reward: -111.13683636016276
# Episode 1662, Total Reward: -116.33107011147413
# Episode 1663, Total Reward: -133.35913615089646
# Episode 1664, Total Reward: -109.44779200418571
# Episode 1665, Total Reward: -128.0283125558439
# Episode 1666, Total Reward: -146.714017525358
# Episode 1667, Total Reward: -108.07961193638916
# Episode 1668, Total Reward: -121.48353093305354
# Episode 1669, Total Reward: -121.84271836626881
# Episode 1670, Total Reward: -118.72441132866247
# Episode 1671, Total Reward: -148.86979881526463
# Episode 1672, Total Reward: -101.09510136183219
# Episode 1673, Total Reward: -114.76258049772008
# Episode 1674, Total Reward: -110.10078830979755
# Episode 1675, Total Reward: -148.67078482960102
# Episode 1676, Total Reward: -124.94594467939625
# Episode 1677, Total Reward: -121.02202639120793
# Episode 1678, Total Reward: -131.60340131598255
# Episode 1679, Total Reward: -129.19485349877544
# Episode 1680, Total Reward: -111.40552379713617
# Episode 1681, Total Reward: -115.49599838843761
# Episode 1682, Total Reward: -85.34365309694819
# Episode 1683, Total Reward: -124.11053347325412
# Episode 1684, Total Reward: -112.05259252078595
# Episode 1685, Total Reward: -90.29365747341629
# Episode 1686, Total Reward: -85.89788041574525
# Episode 1687, Total Reward: -93.41788846555303
# Episode 1688, Total Reward: -129.9490104037228
# Episode 1689, Total Reward: -92.02588874048735
# Episode 1690, Total Reward: -102.06880896613484
# Episode 1691, Total Reward: -130.61966567118566
# Episode 1692, Total Reward: -95.15275147002768
# Episode 1693, Total Reward: -116.18765557971554
# Episode 1694, Total Reward: -90.74229463658702
# Episode 1695, Total Reward: -135.329259884514
# Episode 1696, Total Reward: -84.1709508382482
# Episode 1697, Total Reward: -129.19711605279736
# Episode 1698, Total Reward: -117.67041045037566
# Episode 1699, Total Reward: -142.09356792100107
# Episode 1700, Total Reward: -113.16269138163523
# Checkpoint saved at episode 1700
# Episode 1701, Total Reward: -110.12157068677273
# Episode 1702, Total Reward: -130.3580824320519
# Episode 1703, Total Reward: -94.77368821326687
# Episode 1704, Total Reward: -109.55581163169882
# Episode 1705, Total Reward: -114.70923311617146
# Episode 1706, Total Reward: -128.6176401913475
# Episode 1707, Total Reward: -125.98199281469968
# Episode 1708, Total Reward: -110.1649257351395
# Episode 1709, Total Reward: -118.40538351948865
# Episode 1710, Total Reward: -97.17766938281164
# Episode 1711, Total Reward: -101.5442711725259
# Episode 1712, Total Reward: -119.27091712187783
# Episode 1713, Total Reward: -132.0705744363217
# Episode 1714, Total Reward: -97.17179856641432
# Episode 1715, Total Reward: -106.12811528208145
# Episode 1716, Total Reward: -103.85780585390391
# Episode 1717, Total Reward: -107.25666047014451
# Episode 1718, Total Reward: -117.94340958203504
# Episode 1719, Total Reward: -154.81957501220592
# Episode 1720, Total Reward: -121.00493732631253
# Episode 1721, Total Reward: -128.32941162120053
# Episode 1722, Total Reward: -107.35900234476242
# Episode 1723, Total Reward: -160.33707574355952
# Episode 1724, Total Reward: -117.38952026852218
# Episode 1725, Total Reward: -129.07422413627586
# Episode 1726, Total Reward: -130.72970886195387
# Episode 1727, Total Reward: -90.13211582580918
# Episode 1728, Total Reward: -134.7315898124544
# Episode 1729, Total Reward: -96.49192905866757
# Episode 1730, Total Reward: -133.62675545690556
# Episode 1731, Total Reward: -91.90293330692776
# Episode 1732, Total Reward: -99.71461952988236
# Episode 1733, Total Reward: -104.2212792855411
# Episode 1734, Total Reward: -112.95200160636864
# Episode 1735, Total Reward: -98.34925918146229
# Episode 1736, Total Reward: -117.24834430493001
# Episode 1737, Total Reward: -102.06507148936525
# Episode 1738, Total Reward: -113.28714385961482
# Episode 1739, Total Reward: -126.36335960734132
# Episode 1740, Total Reward: -123.41435783065046
# Episode 1741, Total Reward: -120.32760857941443
# Episode 1742, Total Reward: -117.13227562334752
# Episode 1743, Total Reward: -99.9169256452245
# Episode 1744, Total Reward: -116.66014410716895
# Episode 1745, Total Reward: -124.187795430135
# Episode 1746, Total Reward: -127.27379078450903
# Episode 1747, Total Reward: -108.47786695396896
# Episode 1748, Total Reward: -133.40753132170104
# Episode 1749, Total Reward: -121.42910287918981
# Episode 1750, Total Reward: -117.79362710793424
# Checkpoint saved at episode 1750
# Episode 1751, Total Reward: -95.31847877150066
# Episode 1752, Total Reward: -158.95421964608838
# Episode 1753, Total Reward: -138.73231698738374
# Episode 1754, Total Reward: -195.45691364623445
# Episode 1755, Total Reward: -112.7883120912828
# Episode 1756, Total Reward: -116.00296154905732
# Episode 1757, Total Reward: -111.54325664069549
# Episode 1758, Total Reward: -127.47419534951432
# Episode 1759, Total Reward: -86.95918481993779
# Episode 1760, Total Reward: -135.9160605126847
# Episode 1761, Total Reward: -161.64315066401974
# Episode 1762, Total Reward: -98.93598371568571
# Episode 1763, Total Reward: -140.95216092335482
# Episode 1764, Total Reward: -115.15775303160552
# Episode 1765, Total Reward: -98.69807465630379
# Episode 1766, Total Reward: -88.72420356335924
# Episode 1767, Total Reward: -132.78336881236922
# Episode 1768, Total Reward: -122.2285810489184
# Episode 1769, Total Reward: -90.75259214579589
# Episode 1770, Total Reward: -120.56527945548773
# Episode 1771, Total Reward: -103.91830238210287
# Episode 1772, Total Reward: -108.09744180279769
# Episode 1773, Total Reward: -108.77532311783634
# Episode 1774, Total Reward: -113.66251383694608
# Episode 1775, Total Reward: -125.3039095567137
# Episode 1776, Total Reward: -97.34795888665805

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(episode_rewards)
plt.show()
